# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
from os import listdir
from os.path import isfile
import math

from datetime import datetime
# %load_ext tensorboard

# %%
class SequenceGenerator(keras.utils.Sequence):
    """
    A keras Sequence to be used as an image generator for the model.
    """

    def __init__(self, x, y, batchsize):
        self.x, self.y, self.batchsize = x, y, batchsize

    def __len__(self):
        return math.ceil(len(self.x) / self.batchsize)

    def names_at_batch(self, idx):
        x_names = self.x[idx * self.batchsize:(idx + 1) * self.batchsize]
        y_names = np.asarray(self.y[idx * self.batchsize:(idx + 1) * self.batchsize])
        return x_names, y_names

    def __getitem__(self, idx):
        x_names = self.x[idx * self.batchsize:(idx + 1) * self.batchsize]
        y_names = np.asarray(self.y[idx * self.batchsize:(idx + 1) * self.batchsize])

        # open x image names, resize, normalise and make a numpy array
        x1 = np.asarray([preprocess_input(img_to_array(load_img(file_name[0], target_size=(299, 299)))) for file_name in x_names])
        x2 = np.asarray([preprocess_input(img_to_array(load_img(file_name[1], target_size=(299, 299)))) for file_name in x_names])
        x3 = np.asarray([preprocess_input(img_to_array(load_img(file_name[2], target_size=(299, 299)))) for file_name in x_names])
        # x1 = np.asarray([img_to_array(load_img(file_name[0], target_size=(299, 299))) for file_name in x_names]) / 255.0
        # x2 = np.asarray([img_to_array(load_img(file_name[1], target_size=(299, 299))) for file_name in x_names]) / 255.0
        # x3 = np.asarray([img_to_array(load_img(file_name[2], target_size=(299, 299))) for file_name in x_names]) / 255.0

        return [x1, x2, x3], y_names

    def num_classes(self):
        ret = []
        for cat in self.y:
            if cat not in ret:
                ret.append(cat)
        return len(ret)

# %%
def get_filenames_from_dir(directory):
    x = []
    y = []
    category_count = 0
    for category in listdir(directory):
        triplet = []
        if isfile(category):
            continue
        for file in listdir("{0}/{1}".format(directory, category)):
            if file[-3:] != "jpg":
                continue
            triplet.append(("{0}/{1}/{2}".format(directory, category, file), category_count))
            if len(triplet) == 3:
                x.append([img[0] for img in triplet])
                y.append(triplet[0][1])
                triplet = []
        print(f"{category}: {category_count}")
        category_count += 1

    return x, y

# %%
# makes arrays of the images and label names
x_names, y_names = get_filenames_from_dir("database")

# 15% of all the images are set aside as the test set
x_train_val, x_test, y_train_val, y_test = train_test_split(x_names, y_names, test_size=0.15, random_state=42)

# 17% of the non-test images are set aside as the validation set
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size=0.17, random_state=42)
# Out:
# 1035167: 0
# 1035185: 1
# 1035194: 2
# 1035195: 3
# 1035204: 4
# 1035208: 5
# 1035231: 6
# 1035290: 7
# 1035366: 8
# 1035434: 9
# 1035542: 10
# 1035551: 11
# 1035578: 12
# 1035864: 13
# 1035929: 14
# 1035931: 15
# 1036066: 16
# 1036128: 17
# 1036154: 18
# 1036192: 19
# 1036203: 20
# 1036216: 21
# 1036255: 22
# 1036286: 23
# 1036789: 24
# 1036796: 25
# 1036893: 26
# 1036899: 27
# 1036917: 28
# 1036958: 29
# 1037293: 30
# 1037319: 31
# 1037633: 32
# 4308786: 33
# 4308787: 34
# 4308789: 35
# 4308790: 36
# 4308800: 37
# 4308801: 38
# 4308804: 39
# 4308805: 40
# 4308806: 41
# 4308807: 42
# 4308811: 43
# 4308812: 44
# 4308815: 45
# 4470539: 46
# 4470555: 47
# 4470765: 48
# 4470801: 49
# 4471071: 50
# 4471113: 51
# 4471202: 52
# 4471235: 53
# 4471238: 54
# 4471269: 55
# 4472828: 56
# 4472849: 57
# 4472858: 58
# 4472884: 59
# 4472897: 60
# 4472900: 61
# 4472907: 62
# 4472913: 63
# 4472929: 64
# 4473127: 65
# 4473277: 66
# 4473297: 67
# 4473319: 68
# 4473320: 69
# 4473617: 70
# 4473795: 71
# 4473834: 72
# 4473860: 73
# 4473874: 74
# 4473903: 75
# 4473974: 76
# 4474146: 77
# 4474169: 78
# 4474653: 79
# 4474780: 80
# 4474861: 81
# 4474974: 82
# 4474998: 83
# 4475099: 84
# 4475127: 85
# 4475128: 86
# 4475140: 87
# 4475157: 88
# 4475179: 89
# 4475181: 90
# 4475188: 91
# 4475213: 92
# 4475677: 93
# 4475685: 94
# 4475707: 95
# 4475757: 96
# 4475761: 97
# 4475794: 98
# 4475846: 99
# 4475902: 100
# 4475908: 101
# 4476667: 102
# 4476832: 103
# 4478057: 104
# 4478679: 105
# 4478695: 106
# 4478699: 107
# 4478842: 108
# 4479052: 109
# 4479870: 110
# 4479890: 111
# 4479895: 112
# 4480200: 113
# 4480271: 114
# 4480302: 115
# 4480315: 116
# 4480348: 117
# 4480480: 118
# 4480485: 119
# 4480502: 120
# 4988207: 121
# 4988354: 122
# 4988363: 123
# 4988447: 124
# 4988484: 125
# 4988516: 126
# 5023047: 127
# 5023058: 128
# 5716406: 129
# 5716408: 130
# 5716409: 131
# 5716411: 132
# 5753612: 133
# 5753653: 134
# 5753697: 135
# 5753720: 136
# 5753725: 137
# 5753757: 138
# 5754974: 139
# 5755011: 140
# 5755027: 141
# 5755044: 142
# 5755051: 143
# 5755060: 144
# 5755066: 145
# 5755075: 146
# 5755079: 147
# 5755080: 148
# 5755082: 149
# 5755175: 150
# 5755203: 151
# 5755293: 152
# 5755296: 153
# 5755302: 154
# 5755322: 155
# 5755339: 156
# 5755451: 157
# 5755456: 158
# 5755562: 159
# 5755950: 160
# 5755952: 161
# 5755954: 162
# 5755969: 163
# 5755978: 164
# 5755982: 165
# 5755986: 166
# 5756010: 167
# 5756015: 168
# 5756018: 169
# 5756021: 170
# 5756368: 171
# 5756374: 172
# 5756814: 173
# 5756874: 174
# 5756945: 175
# 5757120: 176
# 5757155: 177
# 5757192: 178
# 5757205: 179
# 5757207: 180
# 5757211: 181
# 5757304: 182
# 5757308: 183
# 5757310: 184
# 5872109: 185
# 5872111: 186
# 5872119: 187
# 5872124: 188
# 5872127: 189
# 5872129: 190
# 5872143: 191
# 5872147: 192
# 5872148: 193
# 5872219: 194
# 5872829: 195
# 5872954: 196
# 5873211: 197
# 5873214: 198
# 5873215: 199
# 5873218: 200
# 5873220: 201
# 5873271: 202
# 5873357: 203
# 5873524: 204
# 5873525: 205
# 6097854: 206
# 6097857: 207
# 6097861: 208
# 6097862: 209
# 6097864: 210
# 6097865: 211
# 6097867: 212
# 6097868: 213
# 6097869: 214
# 6097871: 215
# 6097872: 216
# 6097878: 217
# 6097879: 218
# 6097882: 219
# 6097883: 220
# 6097885: 221
# 6097886: 222
# 6097890: 223
# 6097892: 224
# 6097896: 225
# 6097897: 226
# 6097900: 227
# 6097906: 228
# 6097912: 229
# 6097923: 230
# 6097924: 231
# 6097926: 232
# 6097927: 233
# 6097930: 234
# 7387665: 235
# 7416497: 236
# 7419401: 237
# 7508714: 238
# 7582513: 239
# 7613168: 240
# 7639821: 241
# 7641814: 242
# 7642452: 243
# 7683246: 244
# 7708350: 245
# 7727698: 246
# 7792354: 247
# 7840196: 248
# 7856746: 249
# 7873810: 250
# 7888598: 251
# 7917481: 252
# 7975487: 253
# 8019310: 254
# 8047965: 255
# 8051076: 256
# 8056040: 257
# 8068514: 258
# 8104778: 259
# 8137203: 260
# 8139233: 261
# 8186956: 262
# 8236590: 263
# 8264200: 264
# 8267077: 265
# 8300237: 266
# 8307815: 267
# 8335452: 268
# 8378220: 269
# 8417764: 270
# 8423772: 271
# 8563753: 272
# 8600499: 273
# 8607776: 274
# 9027622: 275
# 9206709: 276
# 9251010: 277
# 9252314: 278
# 9268484: 279
# 9314786: 280
# 9346940: 281
# 9364935: 282
# 9377664: 283
# 9414758: 284
# 9415910: 285
# 9444427: 286
# 9479706: 287
# 9491931: 288
# 9533851: 289
# 9581584: 290

# %%
# make generators with batch size 32 for each set
train_gen = SequenceGenerator(x_train, y_train, 4)
val_gen = SequenceGenerator(x_val, y_val, 4)
test_gen = SequenceGenerator(x_test, y_test, 4)

# %%
ims, ys = train_gen.__getitem__(0)
print(ims)
c = 1
for i in ims:
    plt.subplot(1, 3, c)
    print(i[0].shape)
    plt.imshow(i[0])
    plt.axis('off')
    c += 1

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [array([[[[-0.01960784,  0.02745104, -0.00392157],
#          [-0.02745098,  0.0196079 , -0.01176471],
#          [-0.03529412,  0.01176476, -0.01960784],
#          ...,
#          [-0.00392157,  0.04313731,  0.02745104],
#          [-0.00392157,  0.04313731,  0.02745104],
#          [-0.01176471,  0.03529418,  0.0196079 ]],
#
#         [[-0.04313725,  0.02745104,  0.00392163],
#          [-0.05882353,  0.01176476, -0.01176471],
#          [-0.04313725,  0.00392163, -0.01176471],
#          ...,
#          [ 0.00392163,  0.04313731,  0.06666672],
#          [-0.00392157,  0.03529418,  0.05882359],
#          [-0.01176471,  0.02745104,  0.05098045]],
#
#         [[-0.05882353,  0.01176476,  0.00392163],
#          [-0.05098039,  0.0196079 ,  0.01176476],
#          [-0.04313725,  0.02745104,  0.0196079 ],
#          ...,
#          [ 0.0196079 ,  0.05882359,  0.082353  ],
#          [ 0.01176476,  0.05098045,  0.07450986],
#          [ 0.00392163,  0.04313731,  0.06666672]],
#
#         ...,
#
#         [[ 0.01176476,  0.07450986,  0.09019613],
#          [ 0.02745104,  0.06666672,  0.09019613],
#          [ 0.02745104,  0.06666672,  0.09019613],
#          ...,
#          [ 0.04313731,  0.12156868,  0.13725495],
#          [ 0.04313731,  0.12156868,  0.13725495],
#          [ 0.05098045,  0.12941182,  0.14509809]],
#
#         [[ 0.01176476,  0.07450986,  0.09019613],
#          [ 0.00392163,  0.06666672,  0.082353  ],
#          [ 0.02745104,  0.06666672,  0.09019613],
#          ...,
#          [ 0.05882359,  0.12156868,  0.14509809],
#          [ 0.05882359,  0.12156868,  0.14509809],
#          [ 0.06666672,  0.12941182,  0.15294123]],
#
#         [[ 0.01176476,  0.07450986,  0.09019613],
#          [-0.00392157,  0.05882359,  0.07450986],
#          [ 0.0196079 ,  0.05882359,  0.082353  ],
#          ...,
#          [ 0.06666672,  0.10588241,  0.13725495],
#          [ 0.06666672,  0.10588241,  0.13725495],
#          [ 0.06666672,  0.10588241,  0.13725495]]],
#
#
#        [[[ 0.254902  ,  0.30980396,  0.24705887],
#          [ 0.3803922 ,  0.43529415,  0.37254906],
#          [ 0.41176474,  0.4666667 ,  0.41176474],
#          ...,
#          [ 0.32549024,  0.37254906,  0.27843142],
#          [ 0.30196083,  0.34901965,  0.254902  ],
#          [ 0.21568632,  0.23921573,  0.15294123]],
#
#         [[ 0.22352946,  0.27843142,  0.22352946],
#          [ 0.3803922 ,  0.427451  ,  0.33333337],
#          [ 0.4039216 ,  0.45098042,  0.3411765 ],
#          ...,
#          [ 0.3803922 ,  0.4431373 ,  0.3411765 ],
#          [ 0.32549024,  0.38823533,  0.27058828],
#          [ 0.18431377,  0.254902  ,  0.12156868]],
#
#         [[ 0.22352946,  0.26274514,  0.21568632],
#          [ 0.36470592,  0.41176474,  0.3176471 ],
#          [ 0.4039216 ,  0.45098042,  0.3411765 ],
#          ...,
#          [ 0.34901965,  0.427451  ,  0.3411765 ],
#          [ 0.30980396,  0.38823533,  0.30196083],
#          [ 0.21568632,  0.23921573,  0.18431377]],
#
#         ...,
#
#         [[ 0.41960788,  0.47450984,  0.41960788],
#          [ 0.45098042,  0.5058824 ,  0.4431373 ],
#          [ 0.43529415,  0.5137255 ,  0.4431373 ],
#          ...,
#          [ 0.34901965,  0.427451  ,  0.3411765 ],
#          [ 0.30196083,  0.35686278,  0.2941177 ],
#          [ 0.19215691,  0.254902  ,  0.15294123]],
#
#         [[ 0.4431373 ,  0.49803925,  0.43529415],
#          [ 0.4039216 ,  0.48235297,  0.41176474],
#          [ 0.427451  ,  0.5058824 ,  0.43529415],
#          ...,
#          [ 0.33333337,  0.39607847,  0.30980396],
#          [ 0.26274514,  0.32549024,  0.23921573],
#          [ 0.17647064,  0.21568632,  0.1686275 ]],
#
#         [[ 0.4431373 ,  0.49803925,  0.43529415],
#          [ 0.43529415,  0.5137255 ,  0.4431373 ],
#          [ 0.4431373 ,  0.5372549 ,  0.4431373 ],
#          ...,
#          [ 0.33333337,  0.39607847,  0.30980396],
#          [ 0.27058828,  0.3176471 ,  0.22352946],
#          [ 0.17647064,  0.22352946,  0.14509809]]],
#
#
#        [[[ 0.09019613,  0.13725495,  0.12156868],
#          [ 0.09019613,  0.13725495,  0.10588241],
#          [ 0.09019613,  0.13725495,  0.10588241],
#          ...,
#          [ 0.11372554,  0.19215691,  0.12941182],
#          [ 0.11372554,  0.19215691,  0.12941182],
#          [ 0.12156868,  0.17647064,  0.12156868]],
#
#         [[ 0.09019613,  0.13725495,  0.12156868],
#          [ 0.09019613,  0.13725495,  0.12156868],
#          [ 0.09019613,  0.13725495,  0.12156868],
#          ...,
#          [ 0.11372554,  0.18431377,  0.14509809],
#          [ 0.11372554,  0.18431377,  0.14509809],
#          [ 0.12156868,  0.19215691,  0.15294123]],
#
#         [[ 0.09019613,  0.13725495,  0.12156868],
#          [ 0.09019613,  0.13725495,  0.12156868],
#          [ 0.09019613,  0.13725495,  0.12156868],
#          ...,
#          [ 0.12156868,  0.19215691,  0.15294123],
#          [ 0.12156868,  0.19215691,  0.15294123],
#          [ 0.12156868,  0.19215691,  0.15294123]],
#
#         ...,
#
#         [[ 0.11372554,  0.16078436,  0.14509809],
#          [ 0.12156868,  0.1686275 ,  0.15294123],
#          [ 0.12156868,  0.1686275 ,  0.15294123],
#          ...,
#          [ 0.14509809,  0.21568632,  0.19215691],
#          [ 0.14509809,  0.21568632,  0.19215691],
#          [ 0.12941182,  0.20000005,  0.17647064]],
#
#         [[ 0.12941182,  0.17647064,  0.14509809],
#          [ 0.12941182,  0.17647064,  0.14509809],
#          [ 0.12941182,  0.17647064,  0.14509809],
#          ...,
#          [ 0.16078436,  0.2313726 ,  0.20784318],
#          [ 0.16078436,  0.2313726 ,  0.20784318],
#          [ 0.16078436,  0.2313726 ,  0.20784318]],
#
#         [[ 0.13725495,  0.1686275 ,  0.16078436],
#          [ 0.12156868,  0.1686275 ,  0.15294123],
#          [ 0.12156868,  0.1686275 ,  0.15294123],
#          ...,
#          [ 0.15294123,  0.20000005,  0.20000005],
#          [ 0.15294123,  0.20000005,  0.20000005],
#          [ 0.15294123,  0.20000005,  0.20000005]]],
#
#
#        [[[ 0.254902  ,  0.33333337,  0.34901965],
#          [ 0.254902  ,  0.33333337,  0.34901965],
#          [ 0.27058828,  0.34901965,  0.35686278],
#          ...,
#          [ 0.27058828,  0.34901965,  0.3411765 ],
#          [ 0.27058828,  0.34901965,  0.3411765 ],
#          [ 0.27058828,  0.34901965,  0.3411765 ]],
#
#         [[ 0.254902  ,  0.33333337,  0.34901965],
#          [ 0.254902  ,  0.33333337,  0.34901965],
#          [ 0.26274514,  0.3411765 ,  0.35686278],
#          ...,
#          [ 0.26274514,  0.3411765 ,  0.35686278],
#          [ 0.26274514,  0.3411765 ,  0.35686278],
#          [ 0.26274514,  0.3411765 ,  0.35686278]],
#
#         [[ 0.26274514,  0.3411765 ,  0.35686278],
#          [ 0.26274514,  0.3411765 ,  0.35686278],
#          [ 0.26274514,  0.3411765 ,  0.35686278],
#          ...,
#          [ 0.254902  ,  0.3411765 ,  0.37254906],
#          [ 0.24705887,  0.33333337,  0.36470592],
#          [ 0.24705887,  0.33333337,  0.36470592]],
#
#         ...,
#
#         [[ 0.254902  ,  0.34901965,  0.34901965],
#          [ 0.254902  ,  0.34901965,  0.34901965],
#          [ 0.27058828,  0.36470592,  0.36470592],
#          ...,
#          [ 0.45882356,  0.5058824 ,  0.427451  ],
#          [ 0.45098042,  0.49803925,  0.41960788],
#          [ 0.45098042,  0.49803925,  0.41960788]],
#
#         [[ 0.26274514,  0.35686278,  0.35686278],
#          [ 0.26274514,  0.35686278,  0.35686278],
#          [ 0.27058828,  0.36470592,  0.36470592],
#          ...,
#          [ 0.47450984,  0.49803925,  0.427451  ],
#          [ 0.4666667 ,  0.4901961 ,  0.41960788],
#          [ 0.4666667 ,  0.4901961 ,  0.41960788]],
#
#         [[ 0.27058828,  0.36470592,  0.36470592],
#          [ 0.27058828,  0.36470592,  0.36470592],
#          [ 0.27058828,  0.36470592,  0.36470592],
#          ...,
#          [ 0.4666667 ,  0.4901961 ,  0.41960788],
#          [ 0.45882356,  0.48235297,  0.41176474],
#          [ 0.45882356,  0.48235297,  0.41176474]]]], dtype=float32), array([[[[-0.01960784,  0.01176476,  0.03529418],
#          [-0.04313725, -0.00392157,  0.0196079 ],
#          [-0.04313725,  0.00392163,  0.00392163],
#          ...,
#          [-0.01960784,  0.02745104,  0.02745104],
#          [-0.00392157,  0.02745104,  0.03529418],
#          [-0.00392157,  0.02745104,  0.03529418]],
#
#         [[-0.02745098,  0.00392163,  0.02745104],
#          [-0.04313725, -0.01176471,  0.01176476],
#          [-0.04313725, -0.01176471, -0.00392157],
#          ...,
#          [-0.03529412,  0.01176476,  0.01176476],
#          [-0.01176471,  0.03529418,  0.03529418],
#          [-0.01176471,  0.03529418,  0.03529418]],
#
#         [[-0.04313725, -0.01176471, -0.00392157],
#          [-0.04313725, -0.01176471, -0.00392157],
#          [-0.02745098,  0.00392163,  0.01176476],
#          ...,
#          [-0.01176471,  0.03529418,  0.03529418],
#          [-0.01960784,  0.02745104,  0.02745104],
#          [-0.03529412,  0.03529418,  0.02745104]],
#
#         ...,
#
#         [[-0.05882353, -0.01176471, -0.01176471],
#          [-0.06666666, -0.01960784, -0.01960784],
#          [-0.05098039, -0.00392157, -0.00392157],
#          ...,
#          [-0.01960784,  0.02745104,  0.02745104],
#          [-0.01960784,  0.02745104,  0.02745104],
#          [-0.01960784,  0.02745104,  0.02745104]],
#
#         [[-0.06666666, -0.01960784, -0.03529412],
#          [-0.06666666, -0.01960784, -0.03529412],
#          [-0.04313725,  0.00392163, -0.01176471],
#          ...,
#          [-0.05098039,  0.0196079 ,  0.01176476],
#          [-0.02745098,  0.0196079 ,  0.0196079 ],
#          [-0.01960784,  0.02745104,  0.02745104]],
#
#         [[-0.04313725, -0.01176471, -0.01960784],
#          [-0.05098039, -0.00392157, -0.00392157],
#          [-0.05098039, -0.00392157, -0.00392157],
#          ...,
#          [-0.03529412,  0.03529418,  0.02745104],
#          [-0.03529412,  0.03529418,  0.02745104],
#          [-0.03529412,  0.03529418,  0.02745104]]],
#
#
#        [[[ 0.41960788,  0.47450984,  0.41960788],
#          [ 0.4039216 ,  0.48235297,  0.41176474],
#          [ 0.41176474,  0.49803925,  0.38823533],
#          ...,
#          [ 0.427451  ,  0.5058824 ,  0.4431373 ],
#          [ 0.45098042,  0.5294118 ,  0.45882356],
#          [ 0.4431373 ,  0.52156866,  0.45098042]],
#
#         [[ 0.39607847,  0.45098042,  0.39607847],
#          [ 0.38823533,  0.45882356,  0.41960788],
#          [ 0.41176474,  0.48235297,  0.4431373 ],
#          ...,
#          [ 0.43529415,  0.5294118 ,  0.43529415],
#          [ 0.43529415,  0.5294118 ,  0.45098042],
#          [ 0.427451  ,  0.52156866,  0.4431373 ]],
#
#         [[ 0.4039216 ,  0.45882356,  0.39607847],
#          [ 0.4039216 ,  0.48235297,  0.41960788],
#          [ 0.39607847,  0.47450984,  0.41176474],
#          ...,
#          [ 0.4431373 ,  0.52156866,  0.45098042],
#          [ 0.4431373 ,  0.54509807,  0.41176474],
#          [ 0.41960788,  0.52156866,  0.38823533]],
#
#         ...,
#
#         [[ 0.05882359,  0.12156868,  0.14509809],
#          [ 0.06666672,  0.12941182,  0.15294123],
#          [ 0.07450986,  0.13725495,  0.15294123],
#          ...,
#          [ 0.12156868,  0.19215691,  0.1686275 ],
#          [ 0.12941182,  0.20000005,  0.19215691],
#          [ 0.09803927,  0.16078436,  0.17647064]],
#
#         [[ 0.05882359,  0.13725495,  0.12941182],
#          [ 0.06666672,  0.14509809,  0.13725495],
#          [ 0.082353  ,  0.15294123,  0.14509809],
#          ...,
#          [ 0.11372554,  0.16078436,  0.16078436],
#          [ 0.11372554,  0.19215691,  0.12941182],
#          [ 0.11372554,  0.18431377,  0.14509809]],
#
#         [[ 0.05098045,  0.14509809,  0.12941182],
#          [ 0.05098045,  0.12941182,  0.13725495],
#          [ 0.05098045,  0.12941182,  0.14509809],
#          ...,
#          [ 0.12156868,  0.16078436,  0.18431377],
#          [ 0.10588241,  0.1686275 ,  0.18431377],
#          [ 0.11372554,  0.18431377,  0.17647064]]],
#
#
#        [[[ 0.14509809,  0.19215691,  0.17647064],
#          [ 0.15294123,  0.20000005,  0.18431377],
#          [ 0.16078436,  0.20784318,  0.19215691],
#          ...,
#          [ 0.18431377,  0.26274514,  0.254902  ],
#          [ 0.18431377,  0.26274514,  0.254902  ],
#          [ 0.18431377,  0.26274514,  0.254902  ]],
#
#         [[ 0.14509809,  0.19215691,  0.17647064],
#          [ 0.15294123,  0.20000005,  0.18431377],
#          [ 0.15294123,  0.20000005,  0.18431377],
#          ...,
#          [ 0.18431377,  0.26274514,  0.20000005],
#          [ 0.19215691,  0.27058828,  0.20784318],
#          [ 0.19215691,  0.27843142,  0.21568632]],
#
#         [[ 0.13725495,  0.20784318,  0.1686275 ],
#          [ 0.14509809,  0.21568632,  0.19215691],
#          [ 0.13725495,  0.20784318,  0.18431377],
#          ...,
#          [ 0.18431377,  0.26274514,  0.19215691],
#          [ 0.19215691,  0.27058828,  0.20000005],
#          [ 0.19215691,  0.27058828,  0.20000005]],
#
#         ...,
#
#         [[ 0.14509809,  0.21568632,  0.20784318],
#          [ 0.15294123,  0.22352946,  0.21568632],
#          [ 0.15294123,  0.2313726 ,  0.22352946],
#          ...,
#          [ 0.1686275 ,  0.24705887,  0.254902  ],
#          [ 0.17647064,  0.254902  ,  0.26274514],
#          [ 0.18431377,  0.26274514,  0.27058828]],
#
#         [[ 0.12941182,  0.22352946,  0.20784318],
#          [ 0.13725495,  0.21568632,  0.20784318],
#          [ 0.14509809,  0.2313726 ,  0.20000005],
#          ...,
#          [ 0.18431377,  0.26274514,  0.254902  ],
#          [ 0.19215691,  0.27058828,  0.26274514],
#          [ 0.20000005,  0.27843142,  0.27058828]],
#
#         [[ 0.12941182,  0.20784318,  0.21568632],
#          [ 0.12941182,  0.20784318,  0.21568632],
#          [ 0.13725495,  0.21568632,  0.20784318],
#          ...,
#          [ 0.1686275 ,  0.24705887,  0.254902  ],
#          [ 0.17647064,  0.254902  ,  0.26274514],
#          [ 0.18431377,  0.26274514,  0.27058828]]],
#
#
#        [[[ 0.03529418,  0.12156868,  0.07450986],
#          [ 0.02745104,  0.11372554,  0.06666672],
#          [ 0.0196079 ,  0.10588241,  0.07450986],
#          ...,
#          [ 0.06666672,  0.12941182,  0.14509809],
#          [ 0.06666672,  0.13725495,  0.09803927],
#          [ 0.07450986,  0.14509809,  0.10588241]],
#
#         [[ 0.03529418,  0.10588241,  0.082353  ],
#          [ 0.03529418,  0.10588241,  0.082353  ],
#          [ 0.02745104,  0.09803927,  0.07450986],
#          ...,
#          [ 0.06666672,  0.12941182,  0.14509809],
#          [ 0.06666672,  0.12941182,  0.15294123],
#          [ 0.07450986,  0.13725495,  0.16078436]],
#
#         [[ 0.04313731,  0.11372554,  0.09019613],
#          [ 0.04313731,  0.11372554,  0.09019613],
#          [ 0.04313731,  0.11372554,  0.10588241],
#          ...,
#          [ 0.06666672,  0.12941182,  0.14509809],
#          [ 0.06666672,  0.12941182,  0.15294123],
#          [ 0.06666672,  0.12941182,  0.15294123]],
#
#         ...,
#
#         [[ 0.06666672,  0.13725495,  0.11372554],
#          [ 0.05882359,  0.12941182,  0.10588241],
#          [ 0.05098045,  0.12156868,  0.09803927],
#          ...,
#          [ 0.09019613,  0.13725495,  0.13725495],
#          [ 0.05882359,  0.13725495,  0.14509809],
#          [ 0.05882359,  0.13725495,  0.14509809]],
#
#         [[ 0.05882359,  0.14509809,  0.11372554],
#          [ 0.05098045,  0.13725495,  0.10588241],
#          [ 0.05098045,  0.13725495,  0.10588241],
#          ...,
#          [ 0.06666672,  0.13725495,  0.12941182],
#          [ 0.06666672,  0.14509809,  0.15294123],
#          [ 0.07450986,  0.15294123,  0.16078436]],
#
#         [[ 0.05098045,  0.13725495,  0.09019613],
#          [ 0.05098045,  0.13725495,  0.10588241],
#          [ 0.05882359,  0.14509809,  0.11372554],
#          ...,
#          [ 0.07450986,  0.14509809,  0.13725495],
#          [ 0.06666672,  0.12941182,  0.14509809],
#          [ 0.06666672,  0.12941182,  0.14509809]]]], dtype=float32), array([[[[-0.05098039,  0.01176476,  0.02745104],
#          [-0.05882353,  0.00392163,  0.0196079 ],
#          [-0.04313725,  0.0196079 ,  0.03529418],
#          ...,
#          [ 0.02745104,  0.10588241,  0.04313731],
#          [ 0.02745104,  0.10588241,  0.04313731],
#          [ 0.02745104,  0.10588241,  0.04313731]],
#
#         [[-0.05098039,  0.01176476,  0.02745104],
#          [-0.05882353,  0.00392163,  0.0196079 ],
#          [-0.05098039,  0.01176476,  0.02745104],
#          ...,
#          [ 0.0196079 ,  0.082353  ,  0.09803927],
#          [ 0.0196079 ,  0.082353  ,  0.09803927],
#          [ 0.0196079 ,  0.082353  ,  0.09803927]],
#
#         [[-0.05882353,  0.00392163,  0.0196079 ],
#          [-0.05098039,  0.01176476,  0.02745104],
#          [-0.04313725,  0.0196079 ,  0.03529418],
#          ...,
#          [ 0.01176476,  0.07450986,  0.09019613],
#          [ 0.01176476,  0.07450986,  0.09019613],
#          [ 0.0196079 ,  0.082353  ,  0.09803927]],
#
#         ...,
#
#         [[ 0.04313731,  0.11372554,  0.10588241],
#          [ 0.04313731,  0.11372554,  0.10588241],
#          [ 0.05098045,  0.12156868,  0.11372554],
#          ...,
#          [ 0.05098045,  0.12941182,  0.14509809],
#          [ 0.05098045,  0.12941182,  0.14509809],
#          [ 0.05882359,  0.13725495,  0.15294123]],
#
#         [[ 0.05098045,  0.11372554,  0.12941182],
#          [ 0.05098045,  0.11372554,  0.12941182],
#          [ 0.05882359,  0.12156868,  0.13725495],
#          ...,
#          [ 0.05882359,  0.12941182,  0.1686275 ],
#          [ 0.05098045,  0.12156868,  0.16078436],
#          [ 0.05098045,  0.12156868,  0.16078436]],
#
#         [[ 0.05098045,  0.11372554,  0.13725495],
#          [ 0.05098045,  0.11372554,  0.13725495],
#          [ 0.05098045,  0.11372554,  0.13725495],
#          ...,
#          [ 0.05882359,  0.12941182,  0.1686275 ],
#          [ 0.05098045,  0.12156868,  0.16078436],
#          [ 0.05098045,  0.12156868,  0.16078436]]],
#
#
#        [[[ 0.03529418,  0.10588241,  0.09803927],
#          [ 0.03529418,  0.09803927,  0.11372554],
#          [ 0.04313731,  0.10588241,  0.12156868],
#          ...,
#          [ 0.28627455,  0.2941177 ,  0.18431377],
#          [ 0.27058828,  0.254902  ,  0.15294123],
#          [ 0.26274514,  0.24705887,  0.14509809]],
#
#         [[ 0.03529418,  0.10588241,  0.082353  ],
#          [ 0.04313731,  0.11372554,  0.10588241],
#          [ 0.02745104,  0.09803927,  0.09019613],
#          ...,
#          [ 0.30196083,  0.3176471 ,  0.21568632],
#          [ 0.30196083,  0.27843142,  0.23921573],
#          [ 0.27058828,  0.27058828,  0.20784318]],
#
#         [[ 0.04313731,  0.09019613,  0.07450986],
#          [ 0.03529418,  0.10588241,  0.082353  ],
#          [ 0.03529418,  0.10588241,  0.082353  ],
#          ...,
#          [ 0.2941177 ,  0.2941177 ,  0.20000005],
#          [ 0.30196083,  0.30196083,  0.20784318],
#          [ 0.2941177 ,  0.30196083,  0.19215691]],
#
#         ...,
#
#         [[ 0.2313726 ,  0.2313726 ,  0.15294123],
#          [ 0.2313726 ,  0.23921573,  0.12941182],
#          [ 0.21568632,  0.22352946,  0.082353  ],
#          ...,
#          [ 0.09803927,  0.14509809,  0.12941182],
#          [ 0.082353  ,  0.15294123,  0.14509809],
#          [ 0.09803927,  0.1686275 ,  0.16078436]],
#
#         [[ 0.27843142,  0.28627455,  0.16078436],
#          [ 0.27058828,  0.27843142,  0.13725495],
#          [ 0.26274514,  0.27058828,  0.12941182],
#          ...,
#          [ 0.10588241,  0.15294123,  0.13725495],
#          [ 0.09803927,  0.1686275 ,  0.14509809],
#          [ 0.09803927,  0.1686275 ,  0.14509809]],
#
#         [[ 0.24705887,  0.254902  ,  0.12941182],
#          [ 0.254902  ,  0.26274514,  0.13725495],
#          [ 0.26274514,  0.27058828,  0.16078436],
#          ...,
#          [ 0.10588241,  0.15294123,  0.13725495],
#          [ 0.11372554,  0.16078436,  0.12941182],
#          [ 0.12156868,  0.1686275 ,  0.13725495]]],
#
#
#        [[[ 0.09019613,  0.16078436,  0.15294123],
#          [ 0.09803927,  0.1686275 ,  0.16078436],
#          [ 0.09803927,  0.1686275 ,  0.16078436],
#          ...,
#          [ 0.12156868,  0.17647064,  0.12156868],
#          [ 0.12941182,  0.18431377,  0.12941182],
#          [ 0.12156868,  0.17647064,  0.12156868]],
#
#         [[ 0.10588241,  0.17647064,  0.1686275 ],
#          [ 0.10588241,  0.17647064,  0.1686275 ],
#          [ 0.10588241,  0.17647064,  0.15294123],
#          ...,
#          [ 0.11372554,  0.1686275 ,  0.11372554],
#          [ 0.12156868,  0.17647064,  0.12156868],
#          [ 0.12941182,  0.18431377,  0.12941182]],
#
#         [[ 0.11372554,  0.18431377,  0.16078436],
#          [ 0.10588241,  0.17647064,  0.15294123],
#          [ 0.10588241,  0.17647064,  0.15294123],
#          ...,
#          [ 0.11372554,  0.1686275 ,  0.11372554],
#          [ 0.12156868,  0.17647064,  0.12156868],
#          [ 0.12941182,  0.18431377,  0.12941182]],
#
#         ...,
#
#         [[ 0.17647064,  0.23921573,  0.254902  ],
#          [ 0.17647064,  0.24705887,  0.23921573],
#          [ 0.17647064,  0.24705887,  0.23921573],
#          ...,
#          [ 0.18431377,  0.27058828,  0.23921573],
#          [ 0.17647064,  0.26274514,  0.21568632],
#          [ 0.1686275 ,  0.254902  ,  0.20784318]],
#
#         [[ 0.1686275 ,  0.23921573,  0.2313726 ],
#          [ 0.1686275 ,  0.23921573,  0.2313726 ],
#          [ 0.1686275 ,  0.23921573,  0.21568632],
#          ...,
#          [ 0.18431377,  0.27058828,  0.23921573],
#          [ 0.17647064,  0.26274514,  0.2313726 ],
#          [ 0.1686275 ,  0.254902  ,  0.22352946]],
#
#         [[ 0.17647064,  0.24705887,  0.23921573],
#          [ 0.17647064,  0.24705887,  0.22352946],
#          [ 0.17647064,  0.24705887,  0.22352946],
#          ...,
#          [ 0.18431377,  0.27058828,  0.23921573],
#          [ 0.17647064,  0.26274514,  0.2313726 ],
#          [ 0.1686275 ,  0.254902  ,  0.22352946]]],
#
#
#        [[[ 0.05098045,  0.12941182,  0.14509809],
#          [ 0.06666672,  0.14509809,  0.16078436],
#          [ 0.082353  ,  0.16078436,  0.1686275 ],
#          ...,
#          [ 0.082353  ,  0.1686275 ,  0.13725495],
#          [ 0.09803927,  0.18431377,  0.15294123],
#          [ 0.09019613,  0.18431377,  0.09019613]],
#
#         [[ 0.07450986,  0.15294123,  0.1686275 ],
#          [ 0.082353  ,  0.16078436,  0.1686275 ],
#          [ 0.09019613,  0.1686275 ,  0.17647064],
#          ...,
#          [ 0.082353  ,  0.1686275 ,  0.13725495],
#          [ 0.082353  ,  0.1686275 ,  0.13725495],
#          [ 0.082353  ,  0.15294123,  0.14509809]],
#
#         [[ 0.06666672,  0.12941182,  0.14509809],
#          [ 0.06666672,  0.12941182,  0.14509809],
#          [ 0.082353  ,  0.16078436,  0.15294123],
#          ...,
#          [ 0.082353  ,  0.1686275 ,  0.12156868],
#          [ 0.09019613,  0.16078436,  0.12156868],
#          [ 0.09803927,  0.14509809,  0.12941182]],
#
#         ...,
#
#         [[ 0.09803927,  0.14509809,  0.11372554],
#          [ 0.11372554,  0.16078436,  0.12941182],
#          [ 0.11372554,  0.16078436,  0.14509809],
#          ...,
#          [ 0.09019613,  0.16078436,  0.12156868],
#          [ 0.09019613,  0.16078436,  0.12156868],
#          [ 0.082353  ,  0.15294123,  0.11372554]],
#
#         [[ 0.09019613,  0.16078436,  0.12156868],
#          [ 0.09019613,  0.16078436,  0.12156868],
#          [ 0.09019613,  0.16078436,  0.12156868],
#          ...,
#          [ 0.082353  ,  0.15294123,  0.12941182],
#          [ 0.082353  ,  0.15294123,  0.12941182],
#          [ 0.082353  ,  0.15294123,  0.11372554]],
#
#         [[ 0.07450986,  0.16078436,  0.11372554],
#          [ 0.07450986,  0.16078436,  0.11372554],
#          [ 0.07450986,  0.16078436,  0.11372554],
#          ...,
#          [ 0.07450986,  0.16078436,  0.11372554],
#          [ 0.07450986,  0.16078436,  0.11372554],
#          [ 0.082353  ,  0.15294123,  0.12941182]]]], dtype=float32)]
# (299, 299, 3)
# (299, 299, 3)
# (299, 299, 3)

# %%
# Model 1
base_model1 = InceptionV3(weights="imagenet")
for layer in base_model1.layers:
    layer._name += "_1"
    layer.trainable = True

# Model 2
base_model2 = InceptionV3(weights="imagenet")
for layer in base_model2.layers:
    layer._name += "_2"
    layer.trainable = True

# Model 3
base_model3 = InceptionV3(weights="imagenet")
for layer in base_model3.layers:
    layer._name += "_3"
    layer.trainable = True

# %%
out_layer = keras.layers.add([base_model1.layers[-2].output, base_model2.layers[-2].output, base_model3.layers[-2].output])
predictions = keras.layers.Dense(291, activation='softmax')(out_layer)

model = keras.Model(inputs=[base_model1.input, base_model2.input, base_model3.input], outputs=predictions)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1_1 (InputLayer)          [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_2_2 (InputLayer)          [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_3_3 (InputLayer)          [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 149, 149, 32) 864         input_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_94_2 (Conv2D)            (None, 149, 149, 32) 864         input_2_2[0][0]
# __________________________________________________________________________________________________
# conv2d_188_3 (Conv2D)           (None, 149, 149, 32) 864         input_3_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 149, 149, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94_2 (Batch (None, 149, 149, 32) 96          conv2d_94_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188_3 (Batc (None, 149, 149, 32) 96          conv2d_188_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 149, 149, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_94_2 (Activation)    (None, 149, 149, 32) 0           batch_normalization_94_2[0][0]
# __________________________________________________________________________________________________
# activation_188_3 (Activation)   (None, 149, 149, 32) 0           batch_normalization_188_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1_1 (Conv2D)             (None, 147, 147, 32) 9216        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_95_2 (Conv2D)            (None, 147, 147, 32) 9216        activation_94_2[0][0]
# __________________________________________________________________________________________________
# conv2d_189_3 (Conv2D)           (None, 147, 147, 32) 9216        activation_188_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1_1 (BatchN (None, 147, 147, 32) 96          conv2d_1_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95_2 (Batch (None, 147, 147, 32) 96          conv2d_95_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189_3 (Batc (None, 147, 147, 32) 96          conv2d_189_3[0][0]
# __________________________________________________________________________________________________
# activation_1_1 (Activation)     (None, 147, 147, 32) 0           batch_normalization_1_1[0][0]
# __________________________________________________________________________________________________
# activation_95_2 (Activation)    (None, 147, 147, 32) 0           batch_normalization_95_2[0][0]
# __________________________________________________________________________________________________
# activation_189_3 (Activation)   (None, 147, 147, 32) 0           batch_normalization_189_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2_1 (Conv2D)             (None, 147, 147, 64) 18432       activation_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_96_2 (Conv2D)            (None, 147, 147, 64) 18432       activation_95_2[0][0]
# __________________________________________________________________________________________________
# conv2d_190_3 (Conv2D)           (None, 147, 147, 64) 18432       activation_189_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2_1 (BatchN (None, 147, 147, 64) 192         conv2d_2_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96_2 (Batch (None, 147, 147, 64) 192         conv2d_96_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190_3 (Batc (None, 147, 147, 64) 192         conv2d_190_3[0][0]
# __________________________________________________________________________________________________
# activation_2_1 (Activation)     (None, 147, 147, 64) 0           batch_normalization_2_1[0][0]
# __________________________________________________________________________________________________
# activation_96_2 (Activation)    (None, 147, 147, 64) 0           batch_normalization_96_2[0][0]
# __________________________________________________________________________________________________
# activation_190_3 (Activation)   (None, 147, 147, 64) 0           batch_normalization_190_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 73, 73, 64)   0           activation_2_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4_2 (MaxPooling2D (None, 73, 73, 64)   0           activation_96_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8_3 (MaxPooling2D (None, 73, 73, 64)   0           activation_190_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3_1 (Conv2D)             (None, 73, 73, 80)   5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_97_2 (Conv2D)            (None, 73, 73, 80)   5120        max_pooling2d_4_2[0][0]
# __________________________________________________________________________________________________
# conv2d_191_3 (Conv2D)           (None, 73, 73, 80)   5120        max_pooling2d_8_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3_1 (BatchN (None, 73, 73, 80)   240         conv2d_3_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97_2 (Batch (None, 73, 73, 80)   240         conv2d_97_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191_3 (Batc (None, 73, 73, 80)   240         conv2d_191_3[0][0]
# __________________________________________________________________________________________________
# activation_3_1 (Activation)     (None, 73, 73, 80)   0           batch_normalization_3_1[0][0]
# __________________________________________________________________________________________________
# activation_97_2 (Activation)    (None, 73, 73, 80)   0           batch_normalization_97_2[0][0]
# __________________________________________________________________________________________________
# activation_191_3 (Activation)   (None, 73, 73, 80)   0           batch_normalization_191_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4_1 (Conv2D)             (None, 71, 71, 192)  138240      activation_3_1[0][0]
# __________________________________________________________________________________________________
# conv2d_98_2 (Conv2D)            (None, 71, 71, 192)  138240      activation_97_2[0][0]
# __________________________________________________________________________________________________
# conv2d_192_3 (Conv2D)           (None, 71, 71, 192)  138240      activation_191_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4_1 (BatchN (None, 71, 71, 192)  576         conv2d_4_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98_2 (Batch (None, 71, 71, 192)  576         conv2d_98_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192_3 (Batc (None, 71, 71, 192)  576         conv2d_192_3[0][0]
# __________________________________________________________________________________________________
# activation_4_1 (Activation)     (None, 71, 71, 192)  0           batch_normalization_4_1[0][0]
# __________________________________________________________________________________________________
# activation_98_2 (Activation)    (None, 71, 71, 192)  0           batch_normalization_98_2[0][0]
# __________________________________________________________________________________________________
# activation_192_3 (Activation)   (None, 71, 71, 192)  0           batch_normalization_192_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1_1 (MaxPooling2D (None, 35, 35, 192)  0           activation_4_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5_2 (MaxPooling2D (None, 35, 35, 192)  0           activation_98_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9_3 (MaxPooling2D (None, 35, 35, 192)  0           activation_192_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8_1 (Conv2D)             (None, 35, 35, 64)   12288       max_pooling2d_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_102_2 (Conv2D)           (None, 35, 35, 64)   12288       max_pooling2d_5_2[0][0]
# __________________________________________________________________________________________________
# conv2d_196_3 (Conv2D)           (None, 35, 35, 64)   12288       max_pooling2d_9_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8_1 (BatchN (None, 35, 35, 64)   192         conv2d_8_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102_2 (Batc (None, 35, 35, 64)   192         conv2d_102_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196_3 (Batc (None, 35, 35, 64)   192         conv2d_196_3[0][0]
# __________________________________________________________________________________________________
# activation_8_1 (Activation)     (None, 35, 35, 64)   0           batch_normalization_8_1[0][0]
# __________________________________________________________________________________________________
# activation_102_2 (Activation)   (None, 35, 35, 64)   0           batch_normalization_102_2[0][0]
# __________________________________________________________________________________________________
# activation_196_3 (Activation)   (None, 35, 35, 64)   0           batch_normalization_196_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6_1 (Conv2D)             (None, 35, 35, 48)   9216        max_pooling2d_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9_1 (Conv2D)             (None, 35, 35, 96)   55296       activation_8_1[0][0]
# __________________________________________________________________________________________________
# conv2d_100_2 (Conv2D)           (None, 35, 35, 48)   9216        max_pooling2d_5_2[0][0]
# __________________________________________________________________________________________________
# conv2d_103_2 (Conv2D)           (None, 35, 35, 96)   55296       activation_102_2[0][0]
# __________________________________________________________________________________________________
# conv2d_194_3 (Conv2D)           (None, 35, 35, 48)   9216        max_pooling2d_9_3[0][0]
# __________________________________________________________________________________________________
# conv2d_197_3 (Conv2D)           (None, 35, 35, 96)   55296       activation_196_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6_1 (BatchN (None, 35, 35, 48)   144         conv2d_6_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9_1 (BatchN (None, 35, 35, 96)   288         conv2d_9_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100_2 (Batc (None, 35, 35, 48)   144         conv2d_100_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103_2 (Batc (None, 35, 35, 96)   288         conv2d_103_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194_3 (Batc (None, 35, 35, 48)   144         conv2d_194_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197_3 (Batc (None, 35, 35, 96)   288         conv2d_197_3[0][0]
# __________________________________________________________________________________________________
# activation_6_1 (Activation)     (None, 35, 35, 48)   0           batch_normalization_6_1[0][0]
# __________________________________________________________________________________________________
# activation_9_1 (Activation)     (None, 35, 35, 96)   0           batch_normalization_9_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 192)  0           max_pooling2d_1_1[0][0]
# __________________________________________________________________________________________________
# activation_100_2 (Activation)   (None, 35, 35, 48)   0           batch_normalization_100_2[0][0]
# __________________________________________________________________________________________________
# activation_103_2 (Activation)   (None, 35, 35, 96)   0           batch_normalization_103_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9_2 (AverageP (None, 35, 35, 192)  0           max_pooling2d_5_2[0][0]
# __________________________________________________________________________________________________
# activation_194_3 (Activation)   (None, 35, 35, 48)   0           batch_normalization_194_3[0][0]
# __________________________________________________________________________________________________
# activation_197_3 (Activation)   (None, 35, 35, 96)   0           batch_normalization_197_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_18_3 (Average (None, 35, 35, 192)  0           max_pooling2d_9_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5_1 (Conv2D)             (None, 35, 35, 64)   12288       max_pooling2d_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7_1 (Conv2D)             (None, 35, 35, 64)   76800       activation_6_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10_1 (Conv2D)            (None, 35, 35, 96)   82944       activation_9_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11_1 (Conv2D)            (None, 35, 35, 32)   6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_99_2 (Conv2D)            (None, 35, 35, 64)   12288       max_pooling2d_5_2[0][0]
# __________________________________________________________________________________________________
# conv2d_101_2 (Conv2D)           (None, 35, 35, 64)   76800       activation_100_2[0][0]
# __________________________________________________________________________________________________
# conv2d_104_2 (Conv2D)           (None, 35, 35, 96)   82944       activation_103_2[0][0]
# __________________________________________________________________________________________________
# conv2d_105_2 (Conv2D)           (None, 35, 35, 32)   6144        average_pooling2d_9_2[0][0]
# __________________________________________________________________________________________________
# conv2d_193_3 (Conv2D)           (None, 35, 35, 64)   12288       max_pooling2d_9_3[0][0]
# __________________________________________________________________________________________________
# conv2d_195_3 (Conv2D)           (None, 35, 35, 64)   76800       activation_194_3[0][0]
# __________________________________________________________________________________________________
# conv2d_198_3 (Conv2D)           (None, 35, 35, 96)   82944       activation_197_3[0][0]
# __________________________________________________________________________________________________
# conv2d_199_3 (Conv2D)           (None, 35, 35, 32)   6144        average_pooling2d_18_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5_1 (BatchN (None, 35, 35, 64)   192         conv2d_5_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7_1 (BatchN (None, 35, 35, 64)   192         conv2d_7_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10_1 (Batch (None, 35, 35, 96)   288         conv2d_10_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11_1 (Batch (None, 35, 35, 32)   96          conv2d_11_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99_2 (Batch (None, 35, 35, 64)   192         conv2d_99_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101_2 (Batc (None, 35, 35, 64)   192         conv2d_101_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104_2 (Batc (None, 35, 35, 96)   288         conv2d_104_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105_2 (Batc (None, 35, 35, 32)   96          conv2d_105_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193_3 (Batc (None, 35, 35, 64)   192         conv2d_193_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195_3 (Batc (None, 35, 35, 64)   192         conv2d_195_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198_3 (Batc (None, 35, 35, 96)   288         conv2d_198_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199_3 (Batc (None, 35, 35, 32)   96          conv2d_199_3[0][0]
# __________________________________________________________________________________________________
# activation_5_1 (Activation)     (None, 35, 35, 64)   0           batch_normalization_5_1[0][0]
# __________________________________________________________________________________________________
# activation_7_1 (Activation)     (None, 35, 35, 64)   0           batch_normalization_7_1[0][0]
# __________________________________________________________________________________________________
# activation_10_1 (Activation)    (None, 35, 35, 96)   0           batch_normalization_10_1[0][0]
# __________________________________________________________________________________________________
# activation_11_1 (Activation)    (None, 35, 35, 32)   0           batch_normalization_11_1[0][0]
# __________________________________________________________________________________________________
# activation_99_2 (Activation)    (None, 35, 35, 64)   0           batch_normalization_99_2[0][0]
# __________________________________________________________________________________________________
# activation_101_2 (Activation)   (None, 35, 35, 64)   0           batch_normalization_101_2[0][0]
# __________________________________________________________________________________________________
# activation_104_2 (Activation)   (None, 35, 35, 96)   0           batch_normalization_104_2[0][0]
# __________________________________________________________________________________________________
# activation_105_2 (Activation)   (None, 35, 35, 32)   0           batch_normalization_105_2[0][0]
# __________________________________________________________________________________________________
# activation_193_3 (Activation)   (None, 35, 35, 64)   0           batch_normalization_193_3[0][0]
# __________________________________________________________________________________________________
# activation_195_3 (Activation)   (None, 35, 35, 64)   0           batch_normalization_195_3[0][0]
# __________________________________________________________________________________________________
# activation_198_3 (Activation)   (None, 35, 35, 96)   0           batch_normalization_198_3[0][0]
# __________________________________________________________________________________________________
# activation_199_3 (Activation)   (None, 35, 35, 32)   0           batch_normalization_199_3[0][0]
# __________________________________________________________________________________________________
# mixed0_1 (Concatenate)          (None, 35, 35, 256)  0           activation_5_1[0][0]
#                                                                  activation_7_1[0][0]
#                                                                  activation_10_1[0][0]
#                                                                  activation_11_1[0][0]
# __________________________________________________________________________________________________
# mixed0_2 (Concatenate)          (None, 35, 35, 256)  0           activation_99_2[0][0]
#                                                                  activation_101_2[0][0]
#                                                                  activation_104_2[0][0]
#                                                                  activation_105_2[0][0]
# __________________________________________________________________________________________________
# mixed0_3 (Concatenate)          (None, 35, 35, 256)  0           activation_193_3[0][0]
#                                                                  activation_195_3[0][0]
#                                                                  activation_198_3[0][0]
#                                                                  activation_199_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15_1 (Conv2D)            (None, 35, 35, 64)   16384       mixed0_1[0][0]
# __________________________________________________________________________________________________
# conv2d_109_2 (Conv2D)           (None, 35, 35, 64)   16384       mixed0_2[0][0]
# __________________________________________________________________________________________________
# conv2d_203_3 (Conv2D)           (None, 35, 35, 64)   16384       mixed0_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15_1 (Batch (None, 35, 35, 64)   192         conv2d_15_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109_2 (Batc (None, 35, 35, 64)   192         conv2d_109_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203_3 (Batc (None, 35, 35, 64)   192         conv2d_203_3[0][0]
# __________________________________________________________________________________________________
# activation_15_1 (Activation)    (None, 35, 35, 64)   0           batch_normalization_15_1[0][0]
# __________________________________________________________________________________________________
# activation_109_2 (Activation)   (None, 35, 35, 64)   0           batch_normalization_109_2[0][0]
# __________________________________________________________________________________________________
# activation_203_3 (Activation)   (None, 35, 35, 64)   0           batch_normalization_203_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13_1 (Conv2D)            (None, 35, 35, 48)   12288       mixed0_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16_1 (Conv2D)            (None, 35, 35, 96)   55296       activation_15_1[0][0]
# __________________________________________________________________________________________________
# conv2d_107_2 (Conv2D)           (None, 35, 35, 48)   12288       mixed0_2[0][0]
# __________________________________________________________________________________________________
# conv2d_110_2 (Conv2D)           (None, 35, 35, 96)   55296       activation_109_2[0][0]
# __________________________________________________________________________________________________
# conv2d_201_3 (Conv2D)           (None, 35, 35, 48)   12288       mixed0_3[0][0]
# __________________________________________________________________________________________________
# conv2d_204_3 (Conv2D)           (None, 35, 35, 96)   55296       activation_203_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13_1 (Batch (None, 35, 35, 48)   144         conv2d_13_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16_1 (Batch (None, 35, 35, 96)   288         conv2d_16_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107_2 (Batc (None, 35, 35, 48)   144         conv2d_107_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110_2 (Batc (None, 35, 35, 96)   288         conv2d_110_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201_3 (Batc (None, 35, 35, 48)   144         conv2d_201_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204_3 (Batc (None, 35, 35, 96)   288         conv2d_204_3[0][0]
# __________________________________________________________________________________________________
# activation_13_1 (Activation)    (None, 35, 35, 48)   0           batch_normalization_13_1[0][0]
# __________________________________________________________________________________________________
# activation_16_1 (Activation)    (None, 35, 35, 96)   0           batch_normalization_16_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1_1 (AverageP (None, 35, 35, 256)  0           mixed0_1[0][0]
# __________________________________________________________________________________________________
# activation_107_2 (Activation)   (None, 35, 35, 48)   0           batch_normalization_107_2[0][0]
# __________________________________________________________________________________________________
# activation_110_2 (Activation)   (None, 35, 35, 96)   0           batch_normalization_110_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_10_2 (Average (None, 35, 35, 256)  0           mixed0_2[0][0]
# __________________________________________________________________________________________________
# activation_201_3 (Activation)   (None, 35, 35, 48)   0           batch_normalization_201_3[0][0]
# __________________________________________________________________________________________________
# activation_204_3 (Activation)   (None, 35, 35, 96)   0           batch_normalization_204_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_19_3 (Average (None, 35, 35, 256)  0           mixed0_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12_1 (Conv2D)            (None, 35, 35, 64)   16384       mixed0_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14_1 (Conv2D)            (None, 35, 35, 64)   76800       activation_13_1[0][0]
# __________________________________________________________________________________________________
# conv2d_17_1 (Conv2D)            (None, 35, 35, 96)   82944       activation_16_1[0][0]
# __________________________________________________________________________________________________
# conv2d_18_1 (Conv2D)            (None, 35, 35, 64)   16384       average_pooling2d_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_106_2 (Conv2D)           (None, 35, 35, 64)   16384       mixed0_2[0][0]
# __________________________________________________________________________________________________
# conv2d_108_2 (Conv2D)           (None, 35, 35, 64)   76800       activation_107_2[0][0]
# __________________________________________________________________________________________________
# conv2d_111_2 (Conv2D)           (None, 35, 35, 96)   82944       activation_110_2[0][0]
# __________________________________________________________________________________________________
# conv2d_112_2 (Conv2D)           (None, 35, 35, 64)   16384       average_pooling2d_10_2[0][0]
# __________________________________________________________________________________________________
# conv2d_200_3 (Conv2D)           (None, 35, 35, 64)   16384       mixed0_3[0][0]
# __________________________________________________________________________________________________
# conv2d_202_3 (Conv2D)           (None, 35, 35, 64)   76800       activation_201_3[0][0]
# __________________________________________________________________________________________________
# conv2d_205_3 (Conv2D)           (None, 35, 35, 96)   82944       activation_204_3[0][0]
# __________________________________________________________________________________________________
# conv2d_206_3 (Conv2D)           (None, 35, 35, 64)   16384       average_pooling2d_19_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12_1 (Batch (None, 35, 35, 64)   192         conv2d_12_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14_1 (Batch (None, 35, 35, 64)   192         conv2d_14_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17_1 (Batch (None, 35, 35, 96)   288         conv2d_17_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18_1 (Batch (None, 35, 35, 64)   192         conv2d_18_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106_2 (Batc (None, 35, 35, 64)   192         conv2d_106_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108_2 (Batc (None, 35, 35, 64)   192         conv2d_108_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111_2 (Batc (None, 35, 35, 96)   288         conv2d_111_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112_2 (Batc (None, 35, 35, 64)   192         conv2d_112_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200_3 (Batc (None, 35, 35, 64)   192         conv2d_200_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202_3 (Batc (None, 35, 35, 64)   192         conv2d_202_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205_3 (Batc (None, 35, 35, 96)   288         conv2d_205_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206_3 (Batc (None, 35, 35, 64)   192         conv2d_206_3[0][0]
# __________________________________________________________________________________________________
# activation_12_1 (Activation)    (None, 35, 35, 64)   0           batch_normalization_12_1[0][0]
# __________________________________________________________________________________________________
# activation_14_1 (Activation)    (None, 35, 35, 64)   0           batch_normalization_14_1[0][0]
# __________________________________________________________________________________________________
# activation_17_1 (Activation)    (None, 35, 35, 96)   0           batch_normalization_17_1[0][0]
# __________________________________________________________________________________________________
# activation_18_1 (Activation)    (None, 35, 35, 64)   0           batch_normalization_18_1[0][0]
# __________________________________________________________________________________________________
# activation_106_2 (Activation)   (None, 35, 35, 64)   0           batch_normalization_106_2[0][0]
# __________________________________________________________________________________________________
# activation_108_2 (Activation)   (None, 35, 35, 64)   0           batch_normalization_108_2[0][0]
# __________________________________________________________________________________________________
# activation_111_2 (Activation)   (None, 35, 35, 96)   0           batch_normalization_111_2[0][0]
# __________________________________________________________________________________________________
# activation_112_2 (Activation)   (None, 35, 35, 64)   0           batch_normalization_112_2[0][0]
# __________________________________________________________________________________________________
# activation_200_3 (Activation)   (None, 35, 35, 64)   0           batch_normalization_200_3[0][0]
# __________________________________________________________________________________________________
# activation_202_3 (Activation)   (None, 35, 35, 64)   0           batch_normalization_202_3[0][0]
# __________________________________________________________________________________________________
# activation_205_3 (Activation)   (None, 35, 35, 96)   0           batch_normalization_205_3[0][0]
# __________________________________________________________________________________________________
# activation_206_3 (Activation)   (None, 35, 35, 64)   0           batch_normalization_206_3[0][0]
# __________________________________________________________________________________________________
# mixed1_1 (Concatenate)          (None, 35, 35, 288)  0           activation_12_1[0][0]
#                                                                  activation_14_1[0][0]
#                                                                  activation_17_1[0][0]
#                                                                  activation_18_1[0][0]
# __________________________________________________________________________________________________
# mixed1_2 (Concatenate)          (None, 35, 35, 288)  0           activation_106_2[0][0]
#                                                                  activation_108_2[0][0]
#                                                                  activation_111_2[0][0]
#                                                                  activation_112_2[0][0]
# __________________________________________________________________________________________________
# mixed1_3 (Concatenate)          (None, 35, 35, 288)  0           activation_200_3[0][0]
#                                                                  activation_202_3[0][0]
#                                                                  activation_205_3[0][0]
#                                                                  activation_206_3[0][0]
# __________________________________________________________________________________________________
# conv2d_22_1 (Conv2D)            (None, 35, 35, 64)   18432       mixed1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_116_2 (Conv2D)           (None, 35, 35, 64)   18432       mixed1_2[0][0]
# __________________________________________________________________________________________________
# conv2d_210_3 (Conv2D)           (None, 35, 35, 64)   18432       mixed1_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22_1 (Batch (None, 35, 35, 64)   192         conv2d_22_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116_2 (Batc (None, 35, 35, 64)   192         conv2d_116_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210_3 (Batc (None, 35, 35, 64)   192         conv2d_210_3[0][0]
# __________________________________________________________________________________________________
# activation_22_1 (Activation)    (None, 35, 35, 64)   0           batch_normalization_22_1[0][0]
# __________________________________________________________________________________________________
# activation_116_2 (Activation)   (None, 35, 35, 64)   0           batch_normalization_116_2[0][0]
# __________________________________________________________________________________________________
# activation_210_3 (Activation)   (None, 35, 35, 64)   0           batch_normalization_210_3[0][0]
# __________________________________________________________________________________________________
# conv2d_20_1 (Conv2D)            (None, 35, 35, 48)   13824       mixed1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_23_1 (Conv2D)            (None, 35, 35, 96)   55296       activation_22_1[0][0]
# __________________________________________________________________________________________________
# conv2d_114_2 (Conv2D)           (None, 35, 35, 48)   13824       mixed1_2[0][0]
# __________________________________________________________________________________________________
# conv2d_117_2 (Conv2D)           (None, 35, 35, 96)   55296       activation_116_2[0][0]
# __________________________________________________________________________________________________
# conv2d_208_3 (Conv2D)           (None, 35, 35, 48)   13824       mixed1_3[0][0]
# __________________________________________________________________________________________________
# conv2d_211_3 (Conv2D)           (None, 35, 35, 96)   55296       activation_210_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20_1 (Batch (None, 35, 35, 48)   144         conv2d_20_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23_1 (Batch (None, 35, 35, 96)   288         conv2d_23_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114_2 (Batc (None, 35, 35, 48)   144         conv2d_114_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117_2 (Batc (None, 35, 35, 96)   288         conv2d_117_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_208_3 (Batc (None, 35, 35, 48)   144         conv2d_208_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211_3 (Batc (None, 35, 35, 96)   288         conv2d_211_3[0][0]
# __________________________________________________________________________________________________
# activation_20_1 (Activation)    (None, 35, 35, 48)   0           batch_normalization_20_1[0][0]
# __________________________________________________________________________________________________
# activation_23_1 (Activation)    (None, 35, 35, 96)   0           batch_normalization_23_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2_1 (AverageP (None, 35, 35, 288)  0           mixed1_1[0][0]
# __________________________________________________________________________________________________
# activation_114_2 (Activation)   (None, 35, 35, 48)   0           batch_normalization_114_2[0][0]
# __________________________________________________________________________________________________
# activation_117_2 (Activation)   (None, 35, 35, 96)   0           batch_normalization_117_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_11_2 (Average (None, 35, 35, 288)  0           mixed1_2[0][0]
# __________________________________________________________________________________________________
# activation_208_3 (Activation)   (None, 35, 35, 48)   0           batch_normalization_208_3[0][0]
# __________________________________________________________________________________________________
# activation_211_3 (Activation)   (None, 35, 35, 96)   0           batch_normalization_211_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_20_3 (Average (None, 35, 35, 288)  0           mixed1_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19_1 (Conv2D)            (None, 35, 35, 64)   18432       mixed1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21_1 (Conv2D)            (None, 35, 35, 64)   76800       activation_20_1[0][0]
# __________________________________________________________________________________________________
# conv2d_24_1 (Conv2D)            (None, 35, 35, 96)   82944       activation_23_1[0][0]
# __________________________________________________________________________________________________
# conv2d_25_1 (Conv2D)            (None, 35, 35, 64)   18432       average_pooling2d_2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_113_2 (Conv2D)           (None, 35, 35, 64)   18432       mixed1_2[0][0]
# __________________________________________________________________________________________________
# conv2d_115_2 (Conv2D)           (None, 35, 35, 64)   76800       activation_114_2[0][0]
# __________________________________________________________________________________________________
# conv2d_118_2 (Conv2D)           (None, 35, 35, 96)   82944       activation_117_2[0][0]
# __________________________________________________________________________________________________
# conv2d_119_2 (Conv2D)           (None, 35, 35, 64)   18432       average_pooling2d_11_2[0][0]
# __________________________________________________________________________________________________
# conv2d_207_3 (Conv2D)           (None, 35, 35, 64)   18432       mixed1_3[0][0]
# __________________________________________________________________________________________________
# conv2d_209_3 (Conv2D)           (None, 35, 35, 64)   76800       activation_208_3[0][0]
# ...
# conv2d_87_1 (Conv2D)            (None, 8, 8, 384)    442368      activation_86_1[0][0]
# __________________________________________________________________________________________________
# conv2d_88_1 (Conv2D)            (None, 8, 8, 384)    442368      activation_86_1[0][0]
# __________________________________________________________________________________________________
# conv2d_91_1 (Conv2D)            (None, 8, 8, 384)    442368      activation_90_1[0][0]
# __________________________________________________________________________________________________
# conv2d_92_1 (Conv2D)            (None, 8, 8, 384)    442368      activation_90_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8_1 (AverageP (None, 8, 8, 2048)   0           mixed9_1[0][0]
# __________________________________________________________________________________________________
# conv2d_181_2 (Conv2D)           (None, 8, 8, 384)    442368      activation_180_2[0][0]
# __________________________________________________________________________________________________
# conv2d_182_2 (Conv2D)           (None, 8, 8, 384)    442368      activation_180_2[0][0]
# __________________________________________________________________________________________________
# conv2d_185_2 (Conv2D)           (None, 8, 8, 384)    442368      activation_184_2[0][0]
# __________________________________________________________________________________________________
# conv2d_186_2 (Conv2D)           (None, 8, 8, 384)    442368      activation_184_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_17_2 (Average (None, 8, 8, 2048)   0           mixed9_2[0][0]
# __________________________________________________________________________________________________
# conv2d_275_3 (Conv2D)           (None, 8, 8, 384)    442368      activation_274_3[0][0]
# __________________________________________________________________________________________________
# conv2d_276_3 (Conv2D)           (None, 8, 8, 384)    442368      activation_274_3[0][0]
# __________________________________________________________________________________________________
# conv2d_279_3 (Conv2D)           (None, 8, 8, 384)    442368      activation_278_3[0][0]
# __________________________________________________________________________________________________
# conv2d_280_3 (Conv2D)           (None, 8, 8, 384)    442368      activation_278_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_26_3 (Average (None, 8, 8, 2048)   0           mixed9_3[0][0]
# __________________________________________________________________________________________________
# conv2d_85_1 (Conv2D)            (None, 8, 8, 320)    655360      mixed9_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87_1 (Batch (None, 8, 8, 384)    1152        conv2d_87_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88_1 (Batch (None, 8, 8, 384)    1152        conv2d_88_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91_1 (Batch (None, 8, 8, 384)    1152        conv2d_91_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92_1 (Batch (None, 8, 8, 384)    1152        conv2d_92_1[0][0]
# __________________________________________________________________________________________________
# conv2d_93_1 (Conv2D)            (None, 8, 8, 192)    393216      average_pooling2d_8_1[0][0]
# __________________________________________________________________________________________________
# conv2d_179_2 (Conv2D)           (None, 8, 8, 320)    655360      mixed9_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181_2 (Batc (None, 8, 8, 384)    1152        conv2d_181_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182_2 (Batc (None, 8, 8, 384)    1152        conv2d_182_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185_2 (Batc (None, 8, 8, 384)    1152        conv2d_185_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186_2 (Batc (None, 8, 8, 384)    1152        conv2d_186_2[0][0]
# __________________________________________________________________________________________________
# conv2d_187_2 (Conv2D)           (None, 8, 8, 192)    393216      average_pooling2d_17_2[0][0]
# __________________________________________________________________________________________________
# conv2d_273_3 (Conv2D)           (None, 8, 8, 320)    655360      mixed9_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275_3 (Batc (None, 8, 8, 384)    1152        conv2d_275_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276_3 (Batc (None, 8, 8, 384)    1152        conv2d_276_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279_3 (Batc (None, 8, 8, 384)    1152        conv2d_279_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_280_3 (Batc (None, 8, 8, 384)    1152        conv2d_280_3[0][0]
# __________________________________________________________________________________________________
# conv2d_281_3 (Conv2D)           (None, 8, 8, 192)    393216      average_pooling2d_26_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85_1 (Batch (None, 8, 8, 320)    960         conv2d_85_1[0][0]
# __________________________________________________________________________________________________
# activation_87_1 (Activation)    (None, 8, 8, 384)    0           batch_normalization_87_1[0][0]
# __________________________________________________________________________________________________
# activation_88_1 (Activation)    (None, 8, 8, 384)    0           batch_normalization_88_1[0][0]
# __________________________________________________________________________________________________
# activation_91_1 (Activation)    (None, 8, 8, 384)    0           batch_normalization_91_1[0][0]
# __________________________________________________________________________________________________
# activation_92_1 (Activation)    (None, 8, 8, 384)    0           batch_normalization_92_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93_1 (Batch (None, 8, 8, 192)    576         conv2d_93_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179_2 (Batc (None, 8, 8, 320)    960         conv2d_179_2[0][0]
# __________________________________________________________________________________________________
# activation_181_2 (Activation)   (None, 8, 8, 384)    0           batch_normalization_181_2[0][0]
# __________________________________________________________________________________________________
# activation_182_2 (Activation)   (None, 8, 8, 384)    0           batch_normalization_182_2[0][0]
# __________________________________________________________________________________________________
# activation_185_2 (Activation)   (None, 8, 8, 384)    0           batch_normalization_185_2[0][0]
# __________________________________________________________________________________________________
# activation_186_2 (Activation)   (None, 8, 8, 384)    0           batch_normalization_186_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187_2 (Batc (None, 8, 8, 192)    576         conv2d_187_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273_3 (Batc (None, 8, 8, 320)    960         conv2d_273_3[0][0]
# __________________________________________________________________________________________________
# activation_275_3 (Activation)   (None, 8, 8, 384)    0           batch_normalization_275_3[0][0]
# __________________________________________________________________________________________________
# activation_276_3 (Activation)   (None, 8, 8, 384)    0           batch_normalization_276_3[0][0]
# __________________________________________________________________________________________________
# activation_279_3 (Activation)   (None, 8, 8, 384)    0           batch_normalization_279_3[0][0]
# __________________________________________________________________________________________________
# activation_280_3 (Activation)   (None, 8, 8, 384)    0           batch_normalization_280_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_281_3 (Batc (None, 8, 8, 192)    576         conv2d_281_3[0][0]
# __________________________________________________________________________________________________
# activation_85_1 (Activation)    (None, 8, 8, 320)    0           batch_normalization_85_1[0][0]
# __________________________________________________________________________________________________
# mixed9_1_1 (Concatenate)        (None, 8, 8, 768)    0           activation_87_1[0][0]
#                                                                  activation_88_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1_1 (Concatenate)   (None, 8, 8, 768)    0           activation_91_1[0][0]
#                                                                  activation_92_1[0][0]
# __________________________________________________________________________________________________
# activation_93_1 (Activation)    (None, 8, 8, 192)    0           batch_normalization_93_1[0][0]
# __________________________________________________________________________________________________
# activation_179_2 (Activation)   (None, 8, 8, 320)    0           batch_normalization_179_2[0][0]
# __________________________________________________________________________________________________
# mixed9_1_2 (Concatenate)        (None, 8, 8, 768)    0           activation_181_2[0][0]
#                                                                  activation_182_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3_2 (Concatenate)   (None, 8, 8, 768)    0           activation_185_2[0][0]
#                                                                  activation_186_2[0][0]
# __________________________________________________________________________________________________
# activation_187_2 (Activation)   (None, 8, 8, 192)    0           batch_normalization_187_2[0][0]
# __________________________________________________________________________________________________
# activation_273_3 (Activation)   (None, 8, 8, 320)    0           batch_normalization_273_3[0][0]
# __________________________________________________________________________________________________
# mixed9_1_3 (Concatenate)        (None, 8, 8, 768)    0           activation_275_3[0][0]
#                                                                  activation_276_3[0][0]
# __________________________________________________________________________________________________
# concatenate_5_3 (Concatenate)   (None, 8, 8, 768)    0           activation_279_3[0][0]
#                                                                  activation_280_3[0][0]
# __________________________________________________________________________________________________
# activation_281_3 (Activation)   (None, 8, 8, 192)    0           batch_normalization_281_3[0][0]
# __________________________________________________________________________________________________
# mixed10_1 (Concatenate)         (None, 8, 8, 2048)   0           activation_85_1[0][0]
#                                                                  mixed9_1_1[0][0]
#                                                                  concatenate_1_1[0][0]
#                                                                  activation_93_1[0][0]
# __________________________________________________________________________________________________
# mixed10_2 (Concatenate)         (None, 8, 8, 2048)   0           activation_179_2[0][0]
#                                                                  mixed9_1_2[0][0]
#                                                                  concatenate_3_2[0][0]
#                                                                  activation_187_2[0][0]
# __________________________________________________________________________________________________
# mixed10_3 (Concatenate)         (None, 8, 8, 2048)   0           activation_273_3[0][0]
#                                                                  mixed9_1_3[0][0]
#                                                                  concatenate_5_3[0][0]
#                                                                  activation_281_3[0][0]
# __________________________________________________________________________________________________
# avg_pool_1 (GlobalAveragePoolin (None, 2048)         0           mixed10_1[0][0]
# __________________________________________________________________________________________________
# avg_pool_2 (GlobalAveragePoolin (None, 2048)         0           mixed10_2[0][0]
# __________________________________________________________________________________________________
# avg_pool_3 (GlobalAveragePoolin (None, 2048)         0           mixed10_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 2048)         0           avg_pool_1[0][0]
#                                                                  avg_pool_2[0][0]
#                                                                  avg_pool_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 291)          596259      add[0][0]
# ==================================================================================================
# Total params: 66,004,611
# Trainable params: 65,901,315
# Non-trainable params: 103,296
# __________________________________________________________________________________________________

# %%
logdir = "logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

# %%
model.fit(train_gen, validation_data=val_gen, callbacks=[tensorboard_callback], epochs=20)
# Out:
# C:\Users\zacoa\AppData\Roaming\Python\Python38\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 1/20
# 3709/3709 [==============================] - 823s 213ms/step - loss: 5.5366 - accuracy: 0.0160 - val_loss: 14.3850 - val_accuracy: 0.0095
# Epoch 2/20
# 3709/3709 [==============================] - 770s 208ms/step - loss: 5.1153 - accuracy: 0.0272 - val_loss: 5.6481 - val_accuracy: 0.0494
# Epoch 3/20
# 3709/3709 [==============================] - 779s 210ms/step - loss: 4.6555 - accuracy: 0.0482 - val_loss: 7.9591 - val_accuracy: 0.0355
# Epoch 4/20
# 3709/3709 [==============================] - 783s 211ms/step - loss: 3.9841 - accuracy: 0.1141 - val_loss: 4.4946 - val_accuracy: 0.0800
# Epoch 5/20
# 3709/3709 [==============================] - 786s 212ms/step - loss: 3.2850 - accuracy: 0.2004 - val_loss: 3.9596 - val_accuracy: 0.1642
# Epoch 6/20
# 3709/3709 [==============================] - 775s 209ms/step - loss: 2.7041 - accuracy: 0.2923 - val_loss: 3.9460 - val_accuracy: 0.2294
# Epoch 7/20
# 3709/3709 [==============================] - 782s 211ms/step - loss: 2.2335 - accuracy: 0.3859 - val_loss: 2.5421 - val_accuracy: 0.3337
# Epoch 8/20
# 3709/3709 [==============================] - 779s 210ms/step - loss: 1.8633 - accuracy: 0.4664 - val_loss: 2.0200 - val_accuracy: 0.4281
# Epoch 9/20
# 3709/3709 [==============================] - 771s 208ms/step - loss: 1.5432 - accuracy: 0.5446 - val_loss: 1.9510 - val_accuracy: 0.4636
# Epoch 10/20
# 3709/3709 [==============================] - 777s 210ms/step - loss: 1.2748 - accuracy: 0.6095 - val_loss: 2.1990 - val_accuracy: 0.4274
# Epoch 11/20
# 3709/3709 [==============================] - 777s 210ms/step - loss: 1.0395 - accuracy: 0.6775 - val_loss: 1.8171 - val_accuracy: 0.4768
# Epoch 12/20
# 3709/3709 [==============================] - 775s 209ms/step - loss: 0.8410 - accuracy: 0.7375 - val_loss: 1.7099 - val_accuracy: 0.5153
# Epoch 13/20
# 3709/3709 [==============================] - 783s 211ms/step - loss: 0.6802 - accuracy: 0.7843 - val_loss: 2.5723 - val_accuracy: 0.4715
# Epoch 14/20
# 3709/3709 [==============================] - 771s 208ms/step - loss: 0.5468 - accuracy: 0.8279 - val_loss: 1.6734 - val_accuracy: 0.5778
# Epoch 15/20
# 3709/3709 [==============================] - 782s 211ms/step - loss: 0.4355 - accuracy: 0.8642 - val_loss: 1.4555 - val_accuracy: 0.6334
# Epoch 16/20
# 3709/3709 [==============================] - 773s 208ms/step - loss: 0.3572 - accuracy: 0.8855 - val_loss: 1.7245 - val_accuracy: 0.5739
# Epoch 17/20
# 3709/3709 [==============================] - 775s 209ms/step - loss: 0.2922 - accuracy: 0.9093 - val_loss: 1.6115 - val_accuracy: 0.5867
# Epoch 18/20
# 3709/3709 [==============================] - 776s 209ms/step - loss: 0.2439 - accuracy: 0.9229 - val_loss: 1.7522 - val_accuracy: 0.5989
# Epoch 19/20
# 3709/3709 [==============================] - 778s 210ms/step - loss: 0.2049 - accuracy: 0.9368 - val_loss: 1.8718 - val_accuracy: 0.5749
# Epoch 20/20
# 3709/3709 [==============================] - 772s 208ms/step - loss: 0.1784 - accuracy: 0.9455 - val_loss: 1.9379 - val_accuracy: 0.5805

# %%
model.evaluate(test_gen)
# Out:
# 789/789 [==============================] - 54s 69ms/step - loss: 1.8096 - accuracy: 0.5951
# [1.8095868825912476, 0.5951173305511475]
