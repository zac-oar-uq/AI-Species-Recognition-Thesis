# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from tensorflow import keras
import numpy as np
from os import listdir
from os.path import isfile
import math

# %%
class SequenceGenerator(keras.utils.Sequence):
    """
    A keras Sequence to be used as an image generator for the model.
    """

    def __init__(self, x, y, batchsize):
        self.x, self.y, self.batchsize = x, y, batchsize

    def __len__(self):
        return math.ceil(len(self.x) / self.batchsize)

    def names_at_batch(self, idx):
        x_names = self.x[idx * self.batchsize:(idx + 1) * self.batchsize]
        y_names = np.asarray(self.y[idx * self.batchsize:(idx + 1) * self.batchsize])
        return x_names, y_names

    def __getitem__(self, idx):
        x_names = self.x[idx * self.batchsize:(idx + 1) * self.batchsize]
        y_names = np.asarray(self.y[idx * self.batchsize:(idx + 1) * self.batchsize])
        
        # open x image names, resize, normalise and make a numpy array
        x1 = np.asarray([preprocess_input(img_to_array(load_img(file_name[0], target_size=(299, 299)))) for file_name in x_names])
        x2 = np.asarray([preprocess_input(img_to_array(load_img(file_name[1], target_size=(299, 299)))) for file_name in x_names])
        x3 = np.asarray([preprocess_input(img_to_array(load_img(file_name[2], target_size=(299, 299)))) for file_name in x_names])

        return [x1, x2, x3], y_names

    def num_classes(self):
        ret = []
        for cat in self.y:
            if cat not in ret:
                ret.append(cat)
        return len(ret)

# %%
def get_filenames_from_dir(directory):
    x = []
    y = []
    category_count = 0
    for category in listdir(directory):
        triplet = []
        if isfile(category):
            continue
        for file in listdir("{0}/{1}".format(directory, category)):
            if file[-3:] != "jpg":
                continue
            triplet.append(("{0}/{1}/{2}".format(directory, category, file), category_count))
            if len(triplet) == 3:
                x.append([img[0] for img in triplet])
                y.append(triplet[0][1])
                triplet = []
        category_count += 1

    return x, y

# %%
# makes arrays of the images and label names
x_names, y_names = get_filenames_from_dir("database")

# 15% of all the images are set aside as the test set
x_train_val, x_test, y_train_val, y_test = train_test_split(x_names, y_names, test_size=0.15, random_state=42)

# 17% of the non-test images are set aside as the validation set
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y_train_val, test_size=0.17, random_state=42)

# %%
# make generators with batch size 32 for each set
train_gen = SequenceGenerator(x_train, y_train, 1)
val_gen = SequenceGenerator(x_val, y_val, 1)
test_gen = SequenceGenerator(x_test, y_test, 1)

# %%
# Model 1
base_model1 = InceptionV3(weights="imagenet")
for layer in base_model1.layers:
    layer._name += "_1"
    layer.trainable = True

# Model 2
base_model2 = InceptionV3(weights="imagenet")
for layer in base_model2.layers:
    layer._name += "_2"
    layer.trainable = True

# Model 3
base_model3 = InceptionV3(weights="imagenet")
for layer in base_model3.layers:
    layer._name += "_3"
    layer.trainable = True

# %%
out_layer = keras.layers.add([base_model1.layers[-2].output, base_model2.layers[-2].output, base_model3.layers[-2].output])
predictions = keras.layers.Dense(291, activation='softmax')(out_layer)

model = keras.Model(inputs=[base_model1.input, base_model2.input, base_model3.input], outputs=predictions)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_41_1 (InputLayer)         [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_42_2 (InputLayer)         [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# input_43_3 (InputLayer)         [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d_5409_1 (Conv2D)          (None, 149, 149, 32) 864         input_41_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5503_2 (Conv2D)          (None, 149, 149, 32) 864         input_42_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5597_3 (Conv2D)          (None, 149, 149, 32) 864         input_43_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5408_1 (Bat (None, 149, 149, 32) 96          conv2d_5409_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5502_2 (Bat (None, 149, 149, 32) 96          conv2d_5503_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5596_3 (Bat (None, 149, 149, 32) 96          conv2d_5597_3[0][0]
# __________________________________________________________________________________________________
# activation_5408_1 (Activation)  (None, 149, 149, 32) 0           batch_normalization_5408_1[0][0]
# __________________________________________________________________________________________________
# activation_5502_2 (Activation)  (None, 149, 149, 32) 0           batch_normalization_5502_2[0][0]
# __________________________________________________________________________________________________
# activation_5596_3 (Activation)  (None, 149, 149, 32) 0           batch_normalization_5596_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5410_1 (Conv2D)          (None, 147, 147, 32) 9216        activation_5408_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5504_2 (Conv2D)          (None, 147, 147, 32) 9216        activation_5502_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5598_3 (Conv2D)          (None, 147, 147, 32) 9216        activation_5596_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5409_1 (Bat (None, 147, 147, 32) 96          conv2d_5410_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5503_2 (Bat (None, 147, 147, 32) 96          conv2d_5504_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5597_3 (Bat (None, 147, 147, 32) 96          conv2d_5598_3[0][0]
# __________________________________________________________________________________________________
# activation_5409_1 (Activation)  (None, 147, 147, 32) 0           batch_normalization_5409_1[0][0]
# __________________________________________________________________________________________________
# activation_5503_2 (Activation)  (None, 147, 147, 32) 0           batch_normalization_5503_2[0][0]
# __________________________________________________________________________________________________
# activation_5597_3 (Activation)  (None, 147, 147, 32) 0           batch_normalization_5597_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5411_1 (Conv2D)          (None, 147, 147, 64) 18432       activation_5409_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5505_2 (Conv2D)          (None, 147, 147, 64) 18432       activation_5503_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5599_3 (Conv2D)          (None, 147, 147, 64) 18432       activation_5597_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5410_1 (Bat (None, 147, 147, 64) 192         conv2d_5411_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5504_2 (Bat (None, 147, 147, 64) 192         conv2d_5505_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5598_3 (Bat (None, 147, 147, 64) 192         conv2d_5599_3[0][0]
# __________________________________________________________________________________________________
# activation_5410_1 (Activation)  (None, 147, 147, 64) 0           batch_normalization_5410_1[0][0]
# __________________________________________________________________________________________________
# activation_5504_2 (Activation)  (None, 147, 147, 64) 0           batch_normalization_5504_2[0][0]
# __________________________________________________________________________________________________
# activation_5598_3 (Activation)  (None, 147, 147, 64) 0           batch_normalization_5598_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_233_1 (MaxPooling (None, 73, 73, 64)   0           activation_5410_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_237_2 (MaxPooling (None, 73, 73, 64)   0           activation_5504_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_241_3 (MaxPooling (None, 73, 73, 64)   0           activation_5598_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5412_1 (Conv2D)          (None, 73, 73, 80)   5120        max_pooling2d_233_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5506_2 (Conv2D)          (None, 73, 73, 80)   5120        max_pooling2d_237_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5600_3 (Conv2D)          (None, 73, 73, 80)   5120        max_pooling2d_241_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5411_1 (Bat (None, 73, 73, 80)   240         conv2d_5412_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5505_2 (Bat (None, 73, 73, 80)   240         conv2d_5506_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5599_3 (Bat (None, 73, 73, 80)   240         conv2d_5600_3[0][0]
# __________________________________________________________________________________________________
# activation_5411_1 (Activation)  (None, 73, 73, 80)   0           batch_normalization_5411_1[0][0]
# __________________________________________________________________________________________________
# activation_5505_2 (Activation)  (None, 73, 73, 80)   0           batch_normalization_5505_2[0][0]
# __________________________________________________________________________________________________
# activation_5599_3 (Activation)  (None, 73, 73, 80)   0           batch_normalization_5599_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5413_1 (Conv2D)          (None, 71, 71, 192)  138240      activation_5411_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5507_2 (Conv2D)          (None, 71, 71, 192)  138240      activation_5505_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5601_3 (Conv2D)          (None, 71, 71, 192)  138240      activation_5599_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5412_1 (Bat (None, 71, 71, 192)  576         conv2d_5413_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5506_2 (Bat (None, 71, 71, 192)  576         conv2d_5507_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5600_3 (Bat (None, 71, 71, 192)  576         conv2d_5601_3[0][0]
# __________________________________________________________________________________________________
# activation_5412_1 (Activation)  (None, 71, 71, 192)  0           batch_normalization_5412_1[0][0]
# __________________________________________________________________________________________________
# activation_5506_2 (Activation)  (None, 71, 71, 192)  0           batch_normalization_5506_2[0][0]
# __________________________________________________________________________________________________
# activation_5600_3 (Activation)  (None, 71, 71, 192)  0           batch_normalization_5600_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_234_1 (MaxPooling (None, 35, 35, 192)  0           activation_5412_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_238_2 (MaxPooling (None, 35, 35, 192)  0           activation_5506_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_242_3 (MaxPooling (None, 35, 35, 192)  0           activation_5600_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5417_1 (Conv2D)          (None, 35, 35, 64)   12288       max_pooling2d_234_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5511_2 (Conv2D)          (None, 35, 35, 64)   12288       max_pooling2d_238_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5605_3 (Conv2D)          (None, 35, 35, 64)   12288       max_pooling2d_242_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5416_1 (Bat (None, 35, 35, 64)   192         conv2d_5417_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5510_2 (Bat (None, 35, 35, 64)   192         conv2d_5511_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5604_3 (Bat (None, 35, 35, 64)   192         conv2d_5605_3[0][0]
# __________________________________________________________________________________________________
# activation_5416_1 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5416_1[0][0]
# __________________________________________________________________________________________________
# activation_5510_2 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5510_2[0][0]
# __________________________________________________________________________________________________
# activation_5604_3 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5604_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5415_1 (Conv2D)          (None, 35, 35, 48)   9216        max_pooling2d_234_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5418_1 (Conv2D)          (None, 35, 35, 96)   55296       activation_5416_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5509_2 (Conv2D)          (None, 35, 35, 48)   9216        max_pooling2d_238_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5512_2 (Conv2D)          (None, 35, 35, 96)   55296       activation_5510_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5603_3 (Conv2D)          (None, 35, 35, 48)   9216        max_pooling2d_242_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5606_3 (Conv2D)          (None, 35, 35, 96)   55296       activation_5604_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5414_1 (Bat (None, 35, 35, 48)   144         conv2d_5415_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5417_1 (Bat (None, 35, 35, 96)   288         conv2d_5418_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5508_2 (Bat (None, 35, 35, 48)   144         conv2d_5509_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5511_2 (Bat (None, 35, 35, 96)   288         conv2d_5512_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5602_3 (Bat (None, 35, 35, 48)   144         conv2d_5603_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5605_3 (Bat (None, 35, 35, 96)   288         conv2d_5606_3[0][0]
# __________________________________________________________________________________________________
# activation_5414_1 (Activation)  (None, 35, 35, 48)   0           batch_normalization_5414_1[0][0]
# __________________________________________________________________________________________________
# activation_5417_1 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5417_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_517_1 (Averag (None, 35, 35, 192)  0           max_pooling2d_234_1[0][0]
# __________________________________________________________________________________________________
# activation_5508_2 (Activation)  (None, 35, 35, 48)   0           batch_normalization_5508_2[0][0]
# __________________________________________________________________________________________________
# activation_5511_2 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5511_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_526_2 (Averag (None, 35, 35, 192)  0           max_pooling2d_238_2[0][0]
# __________________________________________________________________________________________________
# activation_5602_3 (Activation)  (None, 35, 35, 48)   0           batch_normalization_5602_3[0][0]
# __________________________________________________________________________________________________
# activation_5605_3 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5605_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_535_3 (Averag (None, 35, 35, 192)  0           max_pooling2d_242_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5414_1 (Conv2D)          (None, 35, 35, 64)   12288       max_pooling2d_234_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5416_1 (Conv2D)          (None, 35, 35, 64)   76800       activation_5414_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5419_1 (Conv2D)          (None, 35, 35, 96)   82944       activation_5417_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5420_1 (Conv2D)          (None, 35, 35, 32)   6144        average_pooling2d_517_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5508_2 (Conv2D)          (None, 35, 35, 64)   12288       max_pooling2d_238_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5510_2 (Conv2D)          (None, 35, 35, 64)   76800       activation_5508_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5513_2 (Conv2D)          (None, 35, 35, 96)   82944       activation_5511_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5514_2 (Conv2D)          (None, 35, 35, 32)   6144        average_pooling2d_526_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5602_3 (Conv2D)          (None, 35, 35, 64)   12288       max_pooling2d_242_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5604_3 (Conv2D)          (None, 35, 35, 64)   76800       activation_5602_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5607_3 (Conv2D)          (None, 35, 35, 96)   82944       activation_5605_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5608_3 (Conv2D)          (None, 35, 35, 32)   6144        average_pooling2d_535_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5413_1 (Bat (None, 35, 35, 64)   192         conv2d_5414_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5415_1 (Bat (None, 35, 35, 64)   192         conv2d_5416_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5418_1 (Bat (None, 35, 35, 96)   288         conv2d_5419_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5419_1 (Bat (None, 35, 35, 32)   96          conv2d_5420_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5507_2 (Bat (None, 35, 35, 64)   192         conv2d_5508_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5509_2 (Bat (None, 35, 35, 64)   192         conv2d_5510_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5512_2 (Bat (None, 35, 35, 96)   288         conv2d_5513_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5513_2 (Bat (None, 35, 35, 32)   96          conv2d_5514_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5601_3 (Bat (None, 35, 35, 64)   192         conv2d_5602_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5603_3 (Bat (None, 35, 35, 64)   192         conv2d_5604_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5606_3 (Bat (None, 35, 35, 96)   288         conv2d_5607_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5607_3 (Bat (None, 35, 35, 32)   96          conv2d_5608_3[0][0]
# __________________________________________________________________________________________________
# activation_5413_1 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5413_1[0][0]
# __________________________________________________________________________________________________
# activation_5415_1 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5415_1[0][0]
# __________________________________________________________________________________________________
# activation_5418_1 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5418_1[0][0]
# __________________________________________________________________________________________________
# activation_5419_1 (Activation)  (None, 35, 35, 32)   0           batch_normalization_5419_1[0][0]
# __________________________________________________________________________________________________
# activation_5507_2 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5507_2[0][0]
# __________________________________________________________________________________________________
# activation_5509_2 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5509_2[0][0]
# __________________________________________________________________________________________________
# activation_5512_2 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5512_2[0][0]
# __________________________________________________________________________________________________
# activation_5513_2 (Activation)  (None, 35, 35, 32)   0           batch_normalization_5513_2[0][0]
# __________________________________________________________________________________________________
# activation_5601_3 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5601_3[0][0]
# __________________________________________________________________________________________________
# activation_5603_3 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5603_3[0][0]
# __________________________________________________________________________________________________
# activation_5606_3 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5606_3[0][0]
# __________________________________________________________________________________________________
# activation_5607_3 (Activation)  (None, 35, 35, 32)   0           batch_normalization_5607_3[0][0]
# __________________________________________________________________________________________________
# mixed0_1 (Concatenate)          (None, 35, 35, 256)  0           activation_5413_1[0][0]
#                                                                  activation_5415_1[0][0]
#                                                                  activation_5418_1[0][0]
#                                                                  activation_5419_1[0][0]
# __________________________________________________________________________________________________
# mixed0_2 (Concatenate)          (None, 35, 35, 256)  0           activation_5507_2[0][0]
#                                                                  activation_5509_2[0][0]
#                                                                  activation_5512_2[0][0]
#                                                                  activation_5513_2[0][0]
# __________________________________________________________________________________________________
# mixed0_3 (Concatenate)          (None, 35, 35, 256)  0           activation_5601_3[0][0]
#                                                                  activation_5603_3[0][0]
#                                                                  activation_5606_3[0][0]
#                                                                  activation_5607_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5424_1 (Conv2D)          (None, 35, 35, 64)   16384       mixed0_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5518_2 (Conv2D)          (None, 35, 35, 64)   16384       mixed0_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5612_3 (Conv2D)          (None, 35, 35, 64)   16384       mixed0_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5423_1 (Bat (None, 35, 35, 64)   192         conv2d_5424_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5517_2 (Bat (None, 35, 35, 64)   192         conv2d_5518_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5611_3 (Bat (None, 35, 35, 64)   192         conv2d_5612_3[0][0]
# __________________________________________________________________________________________________
# activation_5423_1 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5423_1[0][0]
# __________________________________________________________________________________________________
# activation_5517_2 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5517_2[0][0]
# __________________________________________________________________________________________________
# activation_5611_3 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5611_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5422_1 (Conv2D)          (None, 35, 35, 48)   12288       mixed0_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5425_1 (Conv2D)          (None, 35, 35, 96)   55296       activation_5423_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5516_2 (Conv2D)          (None, 35, 35, 48)   12288       mixed0_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5519_2 (Conv2D)          (None, 35, 35, 96)   55296       activation_5517_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5610_3 (Conv2D)          (None, 35, 35, 48)   12288       mixed0_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5613_3 (Conv2D)          (None, 35, 35, 96)   55296       activation_5611_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5421_1 (Bat (None, 35, 35, 48)   144         conv2d_5422_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5424_1 (Bat (None, 35, 35, 96)   288         conv2d_5425_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5515_2 (Bat (None, 35, 35, 48)   144         conv2d_5516_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5518_2 (Bat (None, 35, 35, 96)   288         conv2d_5519_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5609_3 (Bat (None, 35, 35, 48)   144         conv2d_5610_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5612_3 (Bat (None, 35, 35, 96)   288         conv2d_5613_3[0][0]
# __________________________________________________________________________________________________
# activation_5421_1 (Activation)  (None, 35, 35, 48)   0           batch_normalization_5421_1[0][0]
# __________________________________________________________________________________________________
# activation_5424_1 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5424_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_518_1 (Averag (None, 35, 35, 256)  0           mixed0_1[0][0]
# __________________________________________________________________________________________________
# activation_5515_2 (Activation)  (None, 35, 35, 48)   0           batch_normalization_5515_2[0][0]
# __________________________________________________________________________________________________
# activation_5518_2 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5518_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_527_2 (Averag (None, 35, 35, 256)  0           mixed0_2[0][0]
# __________________________________________________________________________________________________
# activation_5609_3 (Activation)  (None, 35, 35, 48)   0           batch_normalization_5609_3[0][0]
# __________________________________________________________________________________________________
# activation_5612_3 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5612_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_536_3 (Averag (None, 35, 35, 256)  0           mixed0_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5421_1 (Conv2D)          (None, 35, 35, 64)   16384       mixed0_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5423_1 (Conv2D)          (None, 35, 35, 64)   76800       activation_5421_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5426_1 (Conv2D)          (None, 35, 35, 96)   82944       activation_5424_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5427_1 (Conv2D)          (None, 35, 35, 64)   16384       average_pooling2d_518_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5515_2 (Conv2D)          (None, 35, 35, 64)   16384       mixed0_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5517_2 (Conv2D)          (None, 35, 35, 64)   76800       activation_5515_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5520_2 (Conv2D)          (None, 35, 35, 96)   82944       activation_5518_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5521_2 (Conv2D)          (None, 35, 35, 64)   16384       average_pooling2d_527_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5609_3 (Conv2D)          (None, 35, 35, 64)   16384       mixed0_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5611_3 (Conv2D)          (None, 35, 35, 64)   76800       activation_5609_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5614_3 (Conv2D)          (None, 35, 35, 96)   82944       activation_5612_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5615_3 (Conv2D)          (None, 35, 35, 64)   16384       average_pooling2d_536_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5420_1 (Bat (None, 35, 35, 64)   192         conv2d_5421_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5422_1 (Bat (None, 35, 35, 64)   192         conv2d_5423_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5425_1 (Bat (None, 35, 35, 96)   288         conv2d_5426_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5426_1 (Bat (None, 35, 35, 64)   192         conv2d_5427_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5514_2 (Bat (None, 35, 35, 64)   192         conv2d_5515_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5516_2 (Bat (None, 35, 35, 64)   192         conv2d_5517_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5519_2 (Bat (None, 35, 35, 96)   288         conv2d_5520_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5520_2 (Bat (None, 35, 35, 64)   192         conv2d_5521_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5608_3 (Bat (None, 35, 35, 64)   192         conv2d_5609_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5610_3 (Bat (None, 35, 35, 64)   192         conv2d_5611_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5613_3 (Bat (None, 35, 35, 96)   288         conv2d_5614_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5614_3 (Bat (None, 35, 35, 64)   192         conv2d_5615_3[0][0]
# __________________________________________________________________________________________________
# activation_5420_1 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5420_1[0][0]
# __________________________________________________________________________________________________
# activation_5422_1 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5422_1[0][0]
# __________________________________________________________________________________________________
# activation_5425_1 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5425_1[0][0]
# __________________________________________________________________________________________________
# activation_5426_1 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5426_1[0][0]
# __________________________________________________________________________________________________
# activation_5514_2 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5514_2[0][0]
# __________________________________________________________________________________________________
# activation_5516_2 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5516_2[0][0]
# __________________________________________________________________________________________________
# activation_5519_2 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5519_2[0][0]
# __________________________________________________________________________________________________
# activation_5520_2 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5520_2[0][0]
# __________________________________________________________________________________________________
# activation_5608_3 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5608_3[0][0]
# __________________________________________________________________________________________________
# activation_5610_3 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5610_3[0][0]
# __________________________________________________________________________________________________
# activation_5613_3 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5613_3[0][0]
# __________________________________________________________________________________________________
# activation_5614_3 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5614_3[0][0]
# __________________________________________________________________________________________________
# mixed1_1 (Concatenate)          (None, 35, 35, 288)  0           activation_5420_1[0][0]
#                                                                  activation_5422_1[0][0]
#                                                                  activation_5425_1[0][0]
#                                                                  activation_5426_1[0][0]
# __________________________________________________________________________________________________
# mixed1_2 (Concatenate)          (None, 35, 35, 288)  0           activation_5514_2[0][0]
#                                                                  activation_5516_2[0][0]
#                                                                  activation_5519_2[0][0]
#                                                                  activation_5520_2[0][0]
# __________________________________________________________________________________________________
# mixed1_3 (Concatenate)          (None, 35, 35, 288)  0           activation_5608_3[0][0]
#                                                                  activation_5610_3[0][0]
#                                                                  activation_5613_3[0][0]
#                                                                  activation_5614_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5431_1 (Conv2D)          (None, 35, 35, 64)   18432       mixed1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5525_2 (Conv2D)          (None, 35, 35, 64)   18432       mixed1_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5619_3 (Conv2D)          (None, 35, 35, 64)   18432       mixed1_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5430_1 (Bat (None, 35, 35, 64)   192         conv2d_5431_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5524_2 (Bat (None, 35, 35, 64)   192         conv2d_5525_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5618_3 (Bat (None, 35, 35, 64)   192         conv2d_5619_3[0][0]
# __________________________________________________________________________________________________
# activation_5430_1 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5430_1[0][0]
# __________________________________________________________________________________________________
# activation_5524_2 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5524_2[0][0]
# __________________________________________________________________________________________________
# activation_5618_3 (Activation)  (None, 35, 35, 64)   0           batch_normalization_5618_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5429_1 (Conv2D)          (None, 35, 35, 48)   13824       mixed1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5432_1 (Conv2D)          (None, 35, 35, 96)   55296       activation_5430_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5523_2 (Conv2D)          (None, 35, 35, 48)   13824       mixed1_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5526_2 (Conv2D)          (None, 35, 35, 96)   55296       activation_5524_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5617_3 (Conv2D)          (None, 35, 35, 48)   13824       mixed1_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5620_3 (Conv2D)          (None, 35, 35, 96)   55296       activation_5618_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5428_1 (Bat (None, 35, 35, 48)   144         conv2d_5429_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5431_1 (Bat (None, 35, 35, 96)   288         conv2d_5432_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5522_2 (Bat (None, 35, 35, 48)   144         conv2d_5523_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5525_2 (Bat (None, 35, 35, 96)   288         conv2d_5526_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5616_3 (Bat (None, 35, 35, 48)   144         conv2d_5617_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5619_3 (Bat (None, 35, 35, 96)   288         conv2d_5620_3[0][0]
# __________________________________________________________________________________________________
# activation_5428_1 (Activation)  (None, 35, 35, 48)   0           batch_normalization_5428_1[0][0]
# __________________________________________________________________________________________________
# activation_5431_1 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5431_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_519_1 (Averag (None, 35, 35, 288)  0           mixed1_1[0][0]
# __________________________________________________________________________________________________
# activation_5522_2 (Activation)  (None, 35, 35, 48)   0           batch_normalization_5522_2[0][0]
# __________________________________________________________________________________________________
# activation_5525_2 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5525_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_528_2 (Averag (None, 35, 35, 288)  0           mixed1_2[0][0]
# __________________________________________________________________________________________________
# activation_5616_3 (Activation)  (None, 35, 35, 48)   0           batch_normalization_5616_3[0][0]
# __________________________________________________________________________________________________
# activation_5619_3 (Activation)  (None, 35, 35, 96)   0           batch_normalization_5619_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_537_3 (Averag (None, 35, 35, 288)  0           mixed1_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5428_1 (Conv2D)          (None, 35, 35, 64)   18432       mixed1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5430_1 (Conv2D)          (None, 35, 35, 64)   76800       activation_5428_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5433_1 (Conv2D)          (None, 35, 35, 96)   82944       activation_5431_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5434_1 (Conv2D)          (None, 35, 35, 64)   18432       average_pooling2d_519_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5522_2 (Conv2D)          (None, 35, 35, 64)   18432       mixed1_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5524_2 (Conv2D)          (None, 35, 35, 64)   76800       activation_5522_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5527_2 (Conv2D)          (None, 35, 35, 96)   82944       activation_5525_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5528_2 (Conv2D)          (None, 35, 35, 64)   18432       average_pooling2d_528_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5616_3 (Conv2D)          (None, 35, 35, 64)   18432       mixed1_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5618_3 (Conv2D)          (None, 35, 35, 64)   76800       activation_5616_3[0][0]
# ...
# conv2d_5496_1 (Conv2D)          (None, 8, 8, 384)    442368      activation_5494_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5497_1 (Conv2D)          (None, 8, 8, 384)    442368      activation_5494_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5500_1 (Conv2D)          (None, 8, 8, 384)    442368      activation_5498_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5501_1 (Conv2D)          (None, 8, 8, 384)    442368      activation_5498_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_525_1 (Averag (None, 8, 8, 2048)   0           mixed9_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5590_2 (Conv2D)          (None, 8, 8, 384)    442368      activation_5588_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5591_2 (Conv2D)          (None, 8, 8, 384)    442368      activation_5588_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5594_2 (Conv2D)          (None, 8, 8, 384)    442368      activation_5592_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5595_2 (Conv2D)          (None, 8, 8, 384)    442368      activation_5592_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_534_2 (Averag (None, 8, 8, 2048)   0           mixed9_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5684_3 (Conv2D)          (None, 8, 8, 384)    442368      activation_5682_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5685_3 (Conv2D)          (None, 8, 8, 384)    442368      activation_5682_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5688_3 (Conv2D)          (None, 8, 8, 384)    442368      activation_5686_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5689_3 (Conv2D)          (None, 8, 8, 384)    442368      activation_5686_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_543_3 (Averag (None, 8, 8, 2048)   0           mixed9_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5494_1 (Conv2D)          (None, 8, 8, 320)    655360      mixed9_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5495_1 (Bat (None, 8, 8, 384)    1152        conv2d_5496_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5496_1 (Bat (None, 8, 8, 384)    1152        conv2d_5497_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5499_1 (Bat (None, 8, 8, 384)    1152        conv2d_5500_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5500_1 (Bat (None, 8, 8, 384)    1152        conv2d_5501_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5502_1 (Conv2D)          (None, 8, 8, 192)    393216      average_pooling2d_525_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5588_2 (Conv2D)          (None, 8, 8, 320)    655360      mixed9_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5589_2 (Bat (None, 8, 8, 384)    1152        conv2d_5590_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5590_2 (Bat (None, 8, 8, 384)    1152        conv2d_5591_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5593_2 (Bat (None, 8, 8, 384)    1152        conv2d_5594_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5594_2 (Bat (None, 8, 8, 384)    1152        conv2d_5595_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5596_2 (Conv2D)          (None, 8, 8, 192)    393216      average_pooling2d_534_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5682_3 (Conv2D)          (None, 8, 8, 320)    655360      mixed9_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5683_3 (Bat (None, 8, 8, 384)    1152        conv2d_5684_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5684_3 (Bat (None, 8, 8, 384)    1152        conv2d_5685_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5687_3 (Bat (None, 8, 8, 384)    1152        conv2d_5688_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5688_3 (Bat (None, 8, 8, 384)    1152        conv2d_5689_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5690_3 (Conv2D)          (None, 8, 8, 192)    393216      average_pooling2d_543_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5493_1 (Bat (None, 8, 8, 320)    960         conv2d_5494_1[0][0]
# __________________________________________________________________________________________________
# activation_5495_1 (Activation)  (None, 8, 8, 384)    0           batch_normalization_5495_1[0][0]
# __________________________________________________________________________________________________
# activation_5496_1 (Activation)  (None, 8, 8, 384)    0           batch_normalization_5496_1[0][0]
# __________________________________________________________________________________________________
# activation_5499_1 (Activation)  (None, 8, 8, 384)    0           batch_normalization_5499_1[0][0]
# __________________________________________________________________________________________________
# activation_5500_1 (Activation)  (None, 8, 8, 384)    0           batch_normalization_5500_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5501_1 (Bat (None, 8, 8, 192)    576         conv2d_5502_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5587_2 (Bat (None, 8, 8, 320)    960         conv2d_5588_2[0][0]
# __________________________________________________________________________________________________
# activation_5589_2 (Activation)  (None, 8, 8, 384)    0           batch_normalization_5589_2[0][0]
# __________________________________________________________________________________________________
# activation_5590_2 (Activation)  (None, 8, 8, 384)    0           batch_normalization_5590_2[0][0]
# __________________________________________________________________________________________________
# activation_5593_2 (Activation)  (None, 8, 8, 384)    0           batch_normalization_5593_2[0][0]
# __________________________________________________________________________________________________
# activation_5594_2 (Activation)  (None, 8, 8, 384)    0           batch_normalization_5594_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5595_2 (Bat (None, 8, 8, 192)    576         conv2d_5596_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5681_3 (Bat (None, 8, 8, 320)    960         conv2d_5682_3[0][0]
# __________________________________________________________________________________________________
# activation_5683_3 (Activation)  (None, 8, 8, 384)    0           batch_normalization_5683_3[0][0]
# __________________________________________________________________________________________________
# activation_5684_3 (Activation)  (None, 8, 8, 384)    0           batch_normalization_5684_3[0][0]
# __________________________________________________________________________________________________
# activation_5687_3 (Activation)  (None, 8, 8, 384)    0           batch_normalization_5687_3[0][0]
# __________________________________________________________________________________________________
# activation_5688_3 (Activation)  (None, 8, 8, 384)    0           batch_normalization_5688_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5689_3 (Bat (None, 8, 8, 192)    576         conv2d_5690_3[0][0]
# __________________________________________________________________________________________________
# activation_5493_1 (Activation)  (None, 8, 8, 320)    0           batch_normalization_5493_1[0][0]
# __________________________________________________________________________________________________
# mixed9_1_1 (Concatenate)        (None, 8, 8, 768)    0           activation_5495_1[0][0]
#                                                                  activation_5496_1[0][0]
# __________________________________________________________________________________________________
# concatenate_123_1 (Concatenate) (None, 8, 8, 768)    0           activation_5499_1[0][0]
#                                                                  activation_5500_1[0][0]
# __________________________________________________________________________________________________
# activation_5501_1 (Activation)  (None, 8, 8, 192)    0           batch_normalization_5501_1[0][0]
# __________________________________________________________________________________________________
# activation_5587_2 (Activation)  (None, 8, 8, 320)    0           batch_normalization_5587_2[0][0]
# __________________________________________________________________________________________________
# mixed9_1_2 (Concatenate)        (None, 8, 8, 768)    0           activation_5589_2[0][0]
#                                                                  activation_5590_2[0][0]
# __________________________________________________________________________________________________
# concatenate_125_2 (Concatenate) (None, 8, 8, 768)    0           activation_5593_2[0][0]
#                                                                  activation_5594_2[0][0]
# __________________________________________________________________________________________________
# activation_5595_2 (Activation)  (None, 8, 8, 192)    0           batch_normalization_5595_2[0][0]
# __________________________________________________________________________________________________
# activation_5681_3 (Activation)  (None, 8, 8, 320)    0           batch_normalization_5681_3[0][0]
# __________________________________________________________________________________________________
# mixed9_1_3 (Concatenate)        (None, 8, 8, 768)    0           activation_5683_3[0][0]
#                                                                  activation_5684_3[0][0]
# __________________________________________________________________________________________________
# concatenate_127_3 (Concatenate) (None, 8, 8, 768)    0           activation_5687_3[0][0]
#                                                                  activation_5688_3[0][0]
# __________________________________________________________________________________________________
# activation_5689_3 (Activation)  (None, 8, 8, 192)    0           batch_normalization_5689_3[0][0]
# __________________________________________________________________________________________________
# mixed10_1 (Concatenate)         (None, 8, 8, 2048)   0           activation_5493_1[0][0]
#                                                                  mixed9_1_1[0][0]
#                                                                  concatenate_123_1[0][0]
#                                                                  activation_5501_1[0][0]
# __________________________________________________________________________________________________
# mixed10_2 (Concatenate)         (None, 8, 8, 2048)   0           activation_5587_2[0][0]
#                                                                  mixed9_1_2[0][0]
#                                                                  concatenate_125_2[0][0]
#                                                                  activation_5595_2[0][0]
# __________________________________________________________________________________________________
# mixed10_3 (Concatenate)         (None, 8, 8, 2048)   0           activation_5681_3[0][0]
#                                                                  mixed9_1_3[0][0]
#                                                                  concatenate_127_3[0][0]
#                                                                  activation_5689_3[0][0]
# __________________________________________________________________________________________________
# avg_pool_1 (GlobalAveragePoolin (None, 2048)         0           mixed10_1[0][0]
# __________________________________________________________________________________________________
# avg_pool_2 (GlobalAveragePoolin (None, 2048)         0           mixed10_2[0][0]
# __________________________________________________________________________________________________
# avg_pool_3 (GlobalAveragePoolin (None, 2048)         0           mixed10_3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 2048)         0           avg_pool_1[0][0]
#                                                                  avg_pool_2[0][0]
#                                                                  avg_pool_3[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 291)          596259      add_10[0][0]
# ==================================================================================================
# Total params: 66,004,611
# Trainable params: 65,901,315
# Non-trainable params: 103,296
# __________________________________________________________________________________________________

# %%
model.fit(train_gen, validation_data=val_gen, epochs=5)
# Out:
# Epoch 1/5
#  2967/14833 [=====>........................] - ETA: 34:20 - loss: 5.8576 - accuracy: 0.0135
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-179-43e8191c592d> in <module>
# ----> 1 model.fit(train_gen, validation_data=val_gen, epochs=5)
#
# ~\AppData\Roaming\Python\Python38\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3037       (graph_function,
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1961         and executing_eagerly):
#    1962       # No tape is watching; skip to running the function.
# -> 1963       return self._build_call_outputs(self._inference_function.call(
#    1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.evaluate(test_gen)
# Out:
# 298/298 [==============================] - 93s 311ms/step - loss: 0.9547 - accuracy: 0.7321
# [0.9546959400177002, 0.7321409583091736]
